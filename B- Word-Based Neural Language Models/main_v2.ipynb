# %%
from keras.preprocessing.text import Tokenizer
import re

import numpy as np
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.sequence import pad_sequences
from pickle import dump, load

# %%
def make_train_seq_prev_words(text, n_pervw=1):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts([text])
    encoded = tokenizer.texts_to_sequences([text])[0]

    sequences = np.array([encoded[i-n_pervw: i+1]
                          for i in range(n_pervw, len(encoded))])

    return \
        sequences[:, :-1], \
        to_categorical(sequences[:, -1], num_classes=len(tokenizer.word_index)+1),\
        tokenizer, \
        n_pervw+1, \
        len(tokenizer.word_index) + 1

# %%
def make_model(X, y, max_len, vocab_size, epo=500):
    model = Sequential()
    model.add(Embedding(vocab_size, 10, input_length=max_len-1))
    model.add(LSTM(50))
    model.add(Dense(vocab_size, activation='softmax'))
    print(model.summary())

    model.compile(loss='categorical_crossentropy',
                  optimizer='adam', metrics=['accuracy'])
    model.fit(X, y, epochs=epo, verbose=2)
    return model

# %%
def gen_top_next_word(model, tokenizer, max_len, seed_text, n_words):

    seq = np.array(tokenizer.texts_to_sequences([seed_text])[0])
    seq = pad_sequences([seq], maxlen=max_len-1, padding='pre')

    yhat = model.predict_on_batch([seq])

    out_text = [tokenizer.index_word[i]
                for i in np.argsort(yhat)[0][::-1][:n_words]]

    return out_text

# %%
with open('data\shortteststory.txt', 'r', encoding='utf-8') as file:
    data = file.read()

# %%
print(data.split()[:200])
# Out:
# ["bill's", 'disappeared', 'upstairs', 'with', 'the', 'little', 'sickly', 'girl', 'but', 'me', "i'm", 'here', 'to', 'see', 'the', 'blind', 'woman', 'i', 'hear', 'she', 'did', 'it', 'on', 'purpose', 'tore', 'donkey', 'tail', 'out', 'of', 'the', 'earth', 'and', 'smeared', 'its', 'milky', 'sap', 'directly', 'in', 'her', 'eyes', 'it', 'must', 'of', 'stung', 'her', 'hands', 'and', 'face', 'bad', 'and', 'maybe', 'left', 'marks', 'on', 'her', 'fingers', 'near', 'santa', 'fe', 'men', 'women', 'and', 'children', 'are', 'always', 'getting', 'possessed', 'of', 'this', 'sort', 'of', 'ecstasy', 'and', 'seem', 'like', 'taking', 'pleasure', 'in', 'swallowing', 'poison', 'and', 'fire', 'and', 'stepping', 'on', 'scorpions', 'and', 'suchlike', 'but', 'it', "ain't", 'superstition', 'like', 'the', 'government', 'try', 'to', 'tell', 'me', 'in', 'the', 'last', 'war', 'superstition', 'i', 'know', "that's", 'when', 'you', 'got', 'to', 'tie', 'your', 'right', 'boot', 'afore', 'your', 'left', 'or', 'when', 'like', 'they', 'say', 'you', 'can', 'shoot', 'your', 'brother', 'when', 'he', 'wears', 'gray', 'but', 'not', 'if', 'he', 'wears', 'blue', 'it', 'does', 'make', 'a', 'sort', 'of', 'sense', 'long', 'as', 'you', "don't", 'look', 'at', 'it', 'head', 'on', 'and', 'just', 'leave', 'it', 'ghostly', 'in', 'the', 'peripheral', 'but', 'bill', "don't", 'like', 'superstition', 'he', 'explained', 'it', 'all', 'to', 'me', 'after', 'we', 'strangled', 'that', 'poor', 'boy', 'at', 'fort', 'smith', 'we', 'done', 'nothing', "'cept", 'kill', "'em", 'for', 'two', 'years', 'and', 'now', "you're", 'boo', 'hooing', 'over', 'another', 'one', 'he']

# %%
words = data.split()
words = [word.lower() for word in words]
clean_words = []

for word in words:
    word = re.sub(r"\"|\?|—|-|\.|:|”|!|\*|;|,|“", ' ', word).strip()
    word = re.sub(r"’", "'", word).strip()
    if word:
        clean_words.append(word)

print(clean_words[:20])
# Out:
# ["bill's", 'disappeared', 'upstairs', 'with', 'the', 'little', 'sickly', 'girl', 'but', 'me', "i'm", 'here', 'to', 'see', 'the', 'blind', 'woman', 'i', 'hear', 'she']

# %%
with open('data\shortteststory.txt', 'w', encoding='utf-8') as file:
    file.write(' '.join(clean_words))

# %%
model_n_prev_versions = {1: None, 2: None}

# %%
for i in model_n_prev_versions:
    X, y, tok, maxlen, vocab_size = make_train_seq_prev_words(clean_words, i)
    model = make_model(X, y, maxlen, vocab_size, epo=400)
    model_n_prev_versions[i] = model
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 1, 10)             9050
#
#  lstm_2 (LSTM)               (None, 50)                12200
#
#  dense_2 (Dense)             (None, 905)               46155
#
# =================================================================
# Total params: 67405 (263.30 KB)
# Trainable params: 67405 (263.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/400
# 70/70 - 2s - loss: 6.7928 - accuracy: 0.0487 - 2s/epoch - 25ms/step
# Epoch 2/400
# 70/70 - 0s - loss: 6.6906 - accuracy: 0.0541 - 136ms/epoch - 2ms/step
# Epoch 3/400
# 70/70 - 0s - loss: 6.3770 - accuracy: 0.0532 - 132ms/epoch - 2ms/step
# Epoch 4/400
# 70/70 - 0s - loss: 5.9602 - accuracy: 0.0532 - 137ms/epoch - 2ms/step
# Epoch 5/400
# 70/70 - 0s - loss: 5.7757 - accuracy: 0.0536 - 149ms/epoch - 2ms/step
# Epoch 6/400
# 70/70 - 0s - loss: 5.6749 - accuracy: 0.0532 - 134ms/epoch - 2ms/step
# Epoch 7/400
# 70/70 - 0s - loss: 5.6072 - accuracy: 0.0532 - 132ms/epoch - 2ms/step
# Epoch 8/400
# 70/70 - 0s - loss: 5.5550 - accuracy: 0.0532 - 134ms/epoch - 2ms/step
# Epoch 9/400
# 70/70 - 0s - loss: 5.5153 - accuracy: 0.0532 - 130ms/epoch - 2ms/step
# Epoch 10/400
# 70/70 - 0s - loss: 5.4819 - accuracy: 0.0532 - 130ms/epoch - 2ms/step
# Epoch 11/400
# 70/70 - 0s - loss: 5.4521 - accuracy: 0.0536 - 130ms/epoch - 2ms/step
# Epoch 12/400
# 70/70 - 0s - loss: 5.4305 - accuracy: 0.0541 - 132ms/epoch - 2ms/step
# Epoch 13/400
# 70/70 - 0s - loss: 5.4087 - accuracy: 0.0545 - 129ms/epoch - 2ms/step
# Epoch 14/400
# 70/70 - 0s - loss: 5.3909 - accuracy: 0.0532 - 136ms/epoch - 2ms/step
# Epoch 15/400
# 70/70 - 0s - loss: 5.3740 - accuracy: 0.0541 - 135ms/epoch - 2ms/step
# Epoch 16/400
# 70/70 - 0s - loss: 5.3602 - accuracy: 0.0550 - 132ms/epoch - 2ms/step
# Epoch 17/400
# 70/70 - 0s - loss: 5.3470 - accuracy: 0.0559 - 136ms/epoch - 2ms/step
# Epoch 18/400
# 70/70 - 0s - loss: 5.3334 - accuracy: 0.0545 - 133ms/epoch - 2ms/step
# Epoch 19/400
# 70/70 - 0s - loss: 5.3214 - accuracy: 0.0559 - 129ms/epoch - 2ms/step
# Epoch 20/400
# 70/70 - 0s - loss: 5.3063 - accuracy: 0.0626 - 132ms/epoch - 2ms/step
# Epoch 21/400
# 70/70 - 0s - loss: 5.2927 - accuracy: 0.0599 - 134ms/epoch - 2ms/step
# Epoch 22/400
# 70/70 - 0s - loss: 5.2767 - accuracy: 0.0702 - 135ms/epoch - 2ms/step
# Epoch 23/400
# 70/70 - 0s - loss: 5.2597 - accuracy: 0.0684 - 138ms/epoch - 2ms/step
# Epoch 24/400
# 70/70 - 0s - loss: 5.2404 - accuracy: 0.0630 - 135ms/epoch - 2ms/step
# Epoch 25/400
# 70/70 - 0s - loss: 5.2193 - accuracy: 0.0715 - 131ms/epoch - 2ms/step
# Epoch 26/400
# 70/70 - 0s - loss: 5.1937 - accuracy: 0.0733 - 129ms/epoch - 2ms/step
# Epoch 27/400
# 70/70 - 0s - loss: 5.1640 - accuracy: 0.0724 - 130ms/epoch - 2ms/step
# Epoch 28/400
# 70/70 - 0s - loss: 5.1285 - accuracy: 0.0800 - 134ms/epoch - 2ms/step
# Epoch 29/400
# 70/70 - 0s - loss: 5.0900 - accuracy: 0.0795 - 131ms/epoch - 2ms/step
# Epoch 30/400
# 70/70 - 0s - loss: 5.0449 - accuracy: 0.0818 - 135ms/epoch - 2ms/step
# Epoch 31/400
# 70/70 - 0s - loss: 4.9943 - accuracy: 0.0885 - 128ms/epoch - 2ms/step
# Epoch 32/400
# 70/70 - 0s - loss: 4.9392 - accuracy: 0.0894 - 131ms/epoch - 2ms/step
# Epoch 33/400
# 70/70 - 0s - loss: 4.8809 - accuracy: 0.0929 - 128ms/epoch - 2ms/step
# Epoch 34/400
# 70/70 - 0s - loss: 4.8214 - accuracy: 0.0952 - 130ms/epoch - 2ms/step
# Epoch 35/400
# 70/70 - 0s - loss: 4.7614 - accuracy: 0.0979 - 130ms/epoch - 2ms/step
# Epoch 36/400
# 70/70 - 0s - loss: 4.7008 - accuracy: 0.1037 - 128ms/epoch - 2ms/step
# Epoch 37/400
# 70/70 - 0s - loss: 4.6371 - accuracy: 0.1090 - 132ms/epoch - 2ms/step
# Epoch 38/400
# 70/70 - 0s - loss: 4.5721 - accuracy: 0.1153 - 134ms/epoch - 2ms/step
# Epoch 39/400
# 70/70 - 0s - loss: 4.5091 - accuracy: 0.1157 - 129ms/epoch - 2ms/step
# Epoch 40/400
# 70/70 - 0s - loss: 4.4449 - accuracy: 0.1157 - 129ms/epoch - 2ms/step
# Epoch 41/400
# 70/70 - 0s - loss: 4.3829 - accuracy: 0.1211 - 129ms/epoch - 2ms/step
# Epoch 42/400
# 70/70 - 0s - loss: 4.3209 - accuracy: 0.1282 - 130ms/epoch - 2ms/step
# Epoch 43/400
# 70/70 - 0s - loss: 4.2599 - accuracy: 0.1323 - 128ms/epoch - 2ms/step
# Epoch 44/400
# 70/70 - 0s - loss: 4.1979 - accuracy: 0.1385 - 147ms/epoch - 2ms/step
# Epoch 45/400
# 70/70 - 0s - loss: 4.1390 - accuracy: 0.1448 - 132ms/epoch - 2ms/step
# Epoch 46/400
# 70/70 - 0s - loss: 4.0792 - accuracy: 0.1600 - 130ms/epoch - 2ms/step
# Epoch 47/400
# 70/70 - 0s - loss: 4.0177 - accuracy: 0.1752 - 132ms/epoch - 2ms/step
# Epoch 48/400
# 70/70 - 0s - loss: 3.9577 - accuracy: 0.1828 - 128ms/epoch - 2ms/step
# Epoch 49/400
# 70/70 - 0s - loss: 3.8967 - accuracy: 0.2011 - 130ms/epoch - 2ms/step
# Epoch 50/400
# 70/70 - 0s - loss: 3.8353 - accuracy: 0.2131 - 129ms/epoch - 2ms/step
# Epoch 51/400
# 70/70 - 0s - loss: 3.7750 - accuracy: 0.2413 - 130ms/epoch - 2ms/step
# Epoch 52/400
# 70/70 - 0s - loss: 3.7130 - accuracy: 0.2475 - 131ms/epoch - 2ms/step
# Epoch 53/400
# 70/70 - 0s - loss: 3.6527 - accuracy: 0.2547 - 133ms/epoch - 2ms/step
# Epoch 54/400
# 70/70 - 0s - loss: 3.5917 - accuracy: 0.2779 - 132ms/epoch - 2ms/step
# Epoch 55/400
# 70/70 - 0s - loss: 3.5334 - accuracy: 0.2815 - 129ms/epoch - 2ms/step
# Epoch 56/400
# 70/70 - 0s - loss: 3.4761 - accuracy: 0.2945 - 129ms/epoch - 2ms/step
# Epoch 57/400
# 70/70 - 0s - loss: 3.4204 - accuracy: 0.3074 - 128ms/epoch - 2ms/step
# Epoch 58/400
# 70/70 - 0s - loss: 3.3659 - accuracy: 0.3132 - 128ms/epoch - 2ms/step
# Epoch 59/400
# 70/70 - 0s - loss: 3.3133 - accuracy: 0.3235 - 129ms/epoch - 2ms/step
# Epoch 60/400
# 70/70 - 0s - loss: 3.2621 - accuracy: 0.3378 - 132ms/epoch - 2ms/step
# Epoch 61/400
# 70/70 - 0s - loss: 3.2118 - accuracy: 0.3503 - 134ms/epoch - 2ms/step
# Epoch 62/400
# 70/70 - 0s - loss: 3.1648 - accuracy: 0.3597 - 130ms/epoch - 2ms/step
# Epoch 63/400
# 70/70 - 0s - loss: 3.1197 - accuracy: 0.3673 - 128ms/epoch - 2ms/step
# Epoch 64/400
# 70/70 - 0s - loss: 3.0751 - accuracy: 0.3722 - 123ms/epoch - 2ms/step
# Epoch 65/400
# 70/70 - 0s - loss: 3.0340 - accuracy: 0.3718 - 121ms/epoch - 2ms/step
# Epoch 66/400
# 70/70 - 0s - loss: 2.9925 - accuracy: 0.3767 - 121ms/epoch - 2ms/step
# Epoch 67/400
# 70/70 - 0s - loss: 2.9542 - accuracy: 0.3843 - 120ms/epoch - 2ms/step
# Epoch 68/400
# 70/70 - 0s - loss: 2.9181 - accuracy: 0.3878 - 120ms/epoch - 2ms/step
# Epoch 69/400
# 70/70 - 0s - loss: 2.8802 - accuracy: 0.3990 - 124ms/epoch - 2ms/step
# Epoch 70/400
# 70/70 - 0s - loss: 2.8444 - accuracy: 0.3986 - 123ms/epoch - 2ms/step
# Epoch 71/400
# 70/70 - 0s - loss: 2.8114 - accuracy: 0.4088 - 120ms/epoch - 2ms/step
# Epoch 72/400
# 70/70 - 0s - loss: 2.7775 - accuracy: 0.4182 - 121ms/epoch - 2ms/step
# Epoch 73/400
# 70/70 - 0s - loss: 2.7443 - accuracy: 0.4236 - 119ms/epoch - 2ms/step
# Epoch 74/400
# 70/70 - 0s - loss: 2.7155 - accuracy: 0.4209 - 122ms/epoch - 2ms/step
# Epoch 75/400
# 70/70 - 0s - loss: 2.6842 - accuracy: 0.4276 - 121ms/epoch - 2ms/step
# Epoch 76/400
# 70/70 - 0s - loss: 2.6559 - accuracy: 0.4245 - 121ms/epoch - 2ms/step
# Epoch 77/400
# 70/70 - 0s - loss: 2.6280 - accuracy: 0.4276 - 124ms/epoch - 2ms/step
# Epoch 78/400
# 70/70 - 0s - loss: 2.6013 - accuracy: 0.4339 - 124ms/epoch - 2ms/step
# Epoch 79/400
# 70/70 - 0s - loss: 2.5768 - accuracy: 0.4245 - 121ms/epoch - 2ms/step
# Epoch 80/400
# 70/70 - 0s - loss: 2.5531 - accuracy: 0.4401 - 121ms/epoch - 2ms/step
# Epoch 81/400
# 70/70 - 0s - loss: 2.5298 - accuracy: 0.4330 - 121ms/epoch - 2ms/step
# Epoch 82/400
# 70/70 - 0s - loss: 2.5065 - accuracy: 0.4343 - 122ms/epoch - 2ms/step
# Epoch 83/400
# 70/70 - 0s - loss: 2.4861 - accuracy: 0.4321 - 123ms/epoch - 2ms/step
# Epoch 84/400
# 70/70 - 0s - loss: 2.4646 - accuracy: 0.4397 - 121ms/epoch - 2ms/step
# Epoch 85/400
# 70/70 - 0s - loss: 2.4456 - accuracy: 0.4357 - 124ms/epoch - 2ms/step
# Epoch 86/400
# 70/70 - 0s - loss: 2.4265 - accuracy: 0.4348 - 121ms/epoch - 2ms/step
# Epoch 87/400
# 70/70 - 0s - loss: 2.4073 - accuracy: 0.4361 - 136ms/epoch - 2ms/step
# Epoch 88/400
# 70/70 - 0s - loss: 2.3894 - accuracy: 0.4343 - 122ms/epoch - 2ms/step
# Epoch 89/400
# 70/70 - 0s - loss: 2.3724 - accuracy: 0.4374 - 121ms/epoch - 2ms/step
# Epoch 90/400
# 70/70 - 0s - loss: 2.3553 - accuracy: 0.4388 - 120ms/epoch - 2ms/step
# Epoch 91/400
# 70/70 - 0s - loss: 2.3398 - accuracy: 0.4397 - 121ms/epoch - 2ms/step
# Epoch 92/400
# 70/70 - 0s - loss: 2.3247 - accuracy: 0.4374 - 120ms/epoch - 2ms/step
# Epoch 93/400
# 70/70 - 0s - loss: 2.3098 - accuracy: 0.4374 - 124ms/epoch - 2ms/step
# Epoch 94/400
# 70/70 - 0s - loss: 2.2958 - accuracy: 0.4321 - 120ms/epoch - 2ms/step
# Epoch 95/400
# 70/70 - 0s - loss: 2.2814 - accuracy: 0.4325 - 124ms/epoch - 2ms/step
# Epoch 96/400
# 70/70 - 0s - loss: 2.2679 - accuracy: 0.4370 - 120ms/epoch - 2ms/step
# Epoch 97/400
# 70/70 - 0s - loss: 2.2553 - accuracy: 0.4383 - 119ms/epoch - 2ms/step
# Epoch 98/400
# 70/70 - 0s - loss: 2.2425 - accuracy: 0.4388 - 121ms/epoch - 2ms/step
# Epoch 99/400
# 70/70 - 0s - loss: 2.2292 - accuracy: 0.4348 - 120ms/epoch - 2ms/step
# Epoch 100/400
# 70/70 - 0s - loss: 2.2185 - accuracy: 0.4392 - 122ms/epoch - 2ms/step
# Epoch 101/400
# 70/70 - 0s - loss: 2.2067 - accuracy: 0.4379 - 124ms/epoch - 2ms/step
# Epoch 102/400
# 70/70 - 0s - loss: 2.1967 - accuracy: 0.4374 - 122ms/epoch - 2ms/step
# Epoch 103/400
# 70/70 - 0s - loss: 2.1850 - accuracy: 0.4361 - 120ms/epoch - 2ms/step
# Epoch 104/400
# 70/70 - 0s - loss: 2.1748 - accuracy: 0.4325 - 125ms/epoch - 2ms/step
# Epoch 105/400
# 70/70 - 0s - loss: 2.1653 - accuracy: 0.4383 - 122ms/epoch - 2ms/step
# Epoch 106/400
# 70/70 - 0s - loss: 2.1544 - accuracy: 0.4334 - 121ms/epoch - 2ms/step
# Epoch 107/400
# 70/70 - 0s - loss: 2.1456 - accuracy: 0.4361 - 122ms/epoch - 2ms/step
# Epoch 108/400
# 70/70 - 0s - loss: 2.1360 - accuracy: 0.4379 - 122ms/epoch - 2ms/step
# Epoch 109/400
# 70/70 - 0s - loss: 2.1266 - accuracy: 0.4325 - 126ms/epoch - 2ms/step
# Epoch 110/400
# 70/70 - 0s - loss: 2.1200 - accuracy: 0.4366 - 121ms/epoch - 2ms/step
# Epoch 111/400
# 70/70 - 0s - loss: 2.1111 - accuracy: 0.4370 - 121ms/epoch - 2ms/step
# Epoch 112/400
# 70/70 - 0s - loss: 2.1026 - accuracy: 0.4366 - 121ms/epoch - 2ms/step
# Epoch 113/400
# 70/70 - 0s - loss: 2.0938 - accuracy: 0.4397 - 123ms/epoch - 2ms/step
# Epoch 114/400
# 70/70 - 0s - loss: 2.0872 - accuracy: 0.4325 - 120ms/epoch - 2ms/step
# Epoch 115/400
# 70/70 - 0s - loss: 2.0801 - accuracy: 0.4321 - 121ms/epoch - 2ms/step
# Epoch 116/400
# 70/70 - 0s - loss: 2.0721 - accuracy: 0.4325 - 121ms/epoch - 2ms/step
# Epoch 117/400
# 70/70 - 0s - loss: 2.0640 - accuracy: 0.4325 - 124ms/epoch - 2ms/step
# Epoch 118/400
# 70/70 - 0s - loss: 2.0587 - accuracy: 0.4374 - 122ms/epoch - 2ms/step
# Epoch 119/400
# 70/70 - 0s - loss: 2.0511 - accuracy: 0.4321 - 122ms/epoch - 2ms/step
# Epoch 120/400
# 70/70 - 0s - loss: 2.0447 - accuracy: 0.4285 - 123ms/epoch - 2ms/step
# Epoch 121/400
# 70/70 - 0s - loss: 2.0409 - accuracy: 0.4285 - 123ms/epoch - 2ms/step
# Epoch 122/400
# 70/70 - 0s - loss: 2.0330 - accuracy: 0.4272 - 136ms/epoch - 2ms/step
# Epoch 123/400
# 70/70 - 0s - loss: 2.0261 - accuracy: 0.4392 - 123ms/epoch - 2ms/step
# Epoch 124/400
# 70/70 - 0s - loss: 2.0202 - accuracy: 0.4276 - 123ms/epoch - 2ms/step
# Epoch 125/400
# 70/70 - 0s - loss: 2.0151 - accuracy: 0.4298 - 123ms/epoch - 2ms/step
# Epoch 126/400
# 70/70 - 0s - loss: 2.0085 - accuracy: 0.4330 - 121ms/epoch - 2ms/step
# Epoch 127/400
# 70/70 - 0s - loss: 2.0050 - accuracy: 0.4316 - 119ms/epoch - 2ms/step
# Epoch 128/400
# 70/70 - 0s - loss: 1.9986 - accuracy: 0.4290 - 121ms/epoch - 2ms/step
# Epoch 129/400
# 70/70 - 0s - loss: 1.9941 - accuracy: 0.4339 - 120ms/epoch - 2ms/step
# Epoch 130/400
# 70/70 - 0s - loss: 1.9885 - accuracy: 0.4281 - 121ms/epoch - 2ms/step
# Epoch 131/400
# 70/70 - 0s - loss: 1.9850 - accuracy: 0.4290 - 121ms/epoch - 2ms/step
# Epoch 132/400
# 70/70 - 0s - loss: 1.9808 - accuracy: 0.4294 - 121ms/epoch - 2ms/step
# Epoch 133/400
# 70/70 - 0s - loss: 1.9764 - accuracy: 0.4352 - 120ms/epoch - 2ms/step
# Epoch 134/400
# 70/70 - 0s - loss: 1.9704 - accuracy: 0.4298 - 123ms/epoch - 2ms/step
# Epoch 135/400
# 70/70 - 0s - loss: 1.9662 - accuracy: 0.4258 - 121ms/epoch - 2ms/step
# Epoch 136/400
# 70/70 - 0s - loss: 1.9606 - accuracy: 0.4366 - 119ms/epoch - 2ms/step
# Epoch 137/400
# 70/70 - 0s - loss: 1.9571 - accuracy: 0.4294 - 122ms/epoch - 2ms/step
# Epoch 138/400
# 70/70 - 0s - loss: 1.9527 - accuracy: 0.4290 - 120ms/epoch - 2ms/step
# Epoch 139/400
# 70/70 - 0s - loss: 1.9509 - accuracy: 0.4263 - 121ms/epoch - 2ms/step
# Epoch 140/400
# 70/70 - 0s - loss: 1.9448 - accuracy: 0.4298 - 120ms/epoch - 2ms/step
# Epoch 141/400
# 70/70 - 0s - loss: 1.9423 - accuracy: 0.4276 - 125ms/epoch - 2ms/step
# Epoch 142/400
# 70/70 - 0s - loss: 1.9377 - accuracy: 0.4258 - 123ms/epoch - 2ms/step
# Epoch 143/400
# 70/70 - 0s - loss: 1.9349 - accuracy: 0.4263 - 121ms/epoch - 2ms/step
# Epoch 144/400
# 70/70 - 0s - loss: 1.9309 - accuracy: 0.4263 - 121ms/epoch - 2ms/step
# Epoch 145/400
# 70/70 - 0s - loss: 1.9267 - accuracy: 0.4325 - 122ms/epoch - 2ms/step
# Epoch 146/400
# 70/70 - 0s - loss: 1.9243 - accuracy: 0.4281 - 122ms/epoch - 2ms/step
# Epoch 147/400
# 70/70 - 0s - loss: 1.9212 - accuracy: 0.4339 - 122ms/epoch - 2ms/step
# Epoch 148/400
# 70/70 - 0s - loss: 1.9174 - accuracy: 0.4303 - 123ms/epoch - 2ms/step
# Epoch 149/400
# 70/70 - 0s - loss: 1.9157 - accuracy: 0.4240 - 124ms/epoch - 2ms/step
# Epoch 150/400
# 70/70 - 0s - loss: 1.9099 - accuracy: 0.4294 - 126ms/epoch - 2ms/step
# Epoch 151/400
# 70/70 - 0s - loss: 1.9083 - accuracy: 0.4240 - 121ms/epoch - 2ms/step
# Epoch 152/400
# 70/70 - 0s - loss: 1.9051 - accuracy: 0.4267 - 120ms/epoch - 2ms/step
# Epoch 153/400
# 70/70 - 0s - loss: 1.9024 - accuracy: 0.4290 - 122ms/epoch - 2ms/step
# Epoch 154/400
# 70/70 - 0s - loss: 1.8998 - accuracy: 0.4303 - 120ms/epoch - 2ms/step
# Epoch 155/400
# 70/70 - 0s - loss: 1.8973 - accuracy: 0.4298 - 123ms/epoch - 2ms/step
# Epoch 156/400
# 70/70 - 0s - loss: 1.8949 - accuracy: 0.4276 - 122ms/epoch - 2ms/step
# Epoch 157/400
# 70/70 - 0s - loss: 1.8927 - accuracy: 0.4263 - 120ms/epoch - 2ms/step
# Epoch 158/400
# 70/70 - 0s - loss: 1.8878 - accuracy: 0.4276 - 124ms/epoch - 2ms/step
# Epoch 159/400
# 70/70 - 0s - loss: 1.8860 - accuracy: 0.4285 - 120ms/epoch - 2ms/step
# Epoch 160/400
# 70/70 - 0s - loss: 1.8834 - accuracy: 0.4227 - 140ms/epoch - 2ms/step
# Epoch 161/400
# 70/70 - 0s - loss: 1.8819 - accuracy: 0.4263 - 121ms/epoch - 2ms/step
# Epoch 162/400
# 70/70 - 0s - loss: 1.8789 - accuracy: 0.4214 - 120ms/epoch - 2ms/step
# Epoch 163/400
# 70/70 - 0s - loss: 1.8763 - accuracy: 0.4307 - 122ms/epoch - 2ms/step
# Epoch 164/400
# 70/70 - 0s - loss: 1.8745 - accuracy: 0.4249 - 122ms/epoch - 2ms/step
# Epoch 165/400
# 70/70 - 0s - loss: 1.8701 - accuracy: 0.4263 - 124ms/epoch - 2ms/step
# Epoch 166/400
# 70/70 - 0s - loss: 1.8700 - accuracy: 0.4276 - 124ms/epoch - 2ms/step
# Epoch 167/400
# 70/70 - 0s - loss: 1.8675 - accuracy: 0.4227 - 121ms/epoch - 2ms/step
# Epoch 168/400
# 70/70 - 0s - loss: 1.8657 - accuracy: 0.4191 - 123ms/epoch - 2ms/step
# Epoch 169/400
# 70/70 - 0s - loss: 1.8639 - accuracy: 0.4303 - 120ms/epoch - 2ms/step
# Epoch 170/400
# 70/70 - 0s - loss: 1.8607 - accuracy: 0.4281 - 121ms/epoch - 2ms/step
# Epoch 171/400
# 70/70 - 0s - loss: 1.8602 - accuracy: 0.4196 - 123ms/epoch - 2ms/step
# Epoch 172/400
# 70/70 - 0s - loss: 1.8567 - accuracy: 0.4258 - 121ms/epoch - 2ms/step
# Epoch 173/400
# 70/70 - 0s - loss: 1.8569 - accuracy: 0.4187 - 122ms/epoch - 2ms/step
# Epoch 174/400
# 70/70 - 0s - loss: 1.8548 - accuracy: 0.4205 - 125ms/epoch - 2ms/step
# Epoch 175/400
# 70/70 - 0s - loss: 1.8521 - accuracy: 0.4218 - 122ms/epoch - 2ms/step
# Epoch 176/400
# 70/70 - 0s - loss: 1.8502 - accuracy: 0.4249 - 121ms/epoch - 2ms/step
# Epoch 177/400
# 70/70 - 0s - loss: 1.8487 - accuracy: 0.4231 - 123ms/epoch - 2ms/step
# Epoch 178/400
# 70/70 - 0s - loss: 1.8468 - accuracy: 0.4254 - 136ms/epoch - 2ms/step
# Epoch 179/400
# 70/70 - 0s - loss: 1.8450 - accuracy: 0.4267 - 139ms/epoch - 2ms/step
# Epoch 180/400
# 70/70 - 0s - loss: 1.8431 - accuracy: 0.4227 - 128ms/epoch - 2ms/step
# Epoch 181/400
# 70/70 - 0s - loss: 1.8416 - accuracy: 0.4209 - 123ms/epoch - 2ms/step
# Epoch 182/400
# 70/70 - 0s - loss: 1.8391 - accuracy: 0.4236 - 124ms/epoch - 2ms/step
# Epoch 183/400
# 70/70 - 0s - loss: 1.8381 - accuracy: 0.4191 - 122ms/epoch - 2ms/step
# Epoch 184/400
# 70/70 - 0s - loss: 1.8366 - accuracy: 0.4298 - 123ms/epoch - 2ms/step
# Epoch 185/400
# 70/70 - 0s - loss: 1.8348 - accuracy: 0.4182 - 120ms/epoch - 2ms/step
# Epoch 186/400
# 70/70 - 0s - loss: 1.8331 - accuracy: 0.4240 - 122ms/epoch - 2ms/step
# Epoch 187/400
# 70/70 - 0s - loss: 1.8321 - accuracy: 0.4196 - 122ms/epoch - 2ms/step
# Epoch 188/400
# 70/70 - 0s - loss: 1.8299 - accuracy: 0.4240 - 122ms/epoch - 2ms/step
# Epoch 189/400
# 70/70 - 0s - loss: 1.8295 - accuracy: 0.4214 - 122ms/epoch - 2ms/step
# Epoch 190/400
# 70/70 - 0s - loss: 1.8268 - accuracy: 0.4196 - 126ms/epoch - 2ms/step
# Epoch 191/400
# 70/70 - 0s - loss: 1.8266 - accuracy: 0.4263 - 121ms/epoch - 2ms/step
# Epoch 192/400
# 70/70 - 0s - loss: 1.8246 - accuracy: 0.4169 - 121ms/epoch - 2ms/step
# Epoch 193/400
# 70/70 - 0s - loss: 1.8223 - accuracy: 0.4187 - 121ms/epoch - 2ms/step
# Epoch 194/400
# 70/70 - 0s - loss: 1.8213 - accuracy: 0.4249 - 121ms/epoch - 2ms/step
# Epoch 195/400
# 70/70 - 0s - loss: 1.8220 - accuracy: 0.4173 - 140ms/epoch - 2ms/step
# Epoch 196/400
# 70/70 - 0s - loss: 1.8199 - accuracy: 0.4236 - 124ms/epoch - 2ms/step
# Epoch 197/400
# 70/70 - 0s - loss: 1.8171 - accuracy: 0.4187 - 124ms/epoch - 2ms/step
# Epoch 198/400
# 70/70 - 0s - loss: 1.8167 - accuracy: 0.4182 - 126ms/epoch - 2ms/step
# Epoch 199/400
# 70/70 - 0s - loss: 1.8166 - accuracy: 0.4200 - 121ms/epoch - 2ms/step
# Epoch 200/400
# 70/70 - 0s - loss: 1.8137 - accuracy: 0.4218 - 122ms/epoch - 2ms/step
# Epoch 201/400
# 70/70 - 0s - loss: 1.8135 - accuracy: 0.4214 - 122ms/epoch - 2ms/step
# Epoch 202/400
# 70/70 - 0s - loss: 1.8117 - accuracy: 0.4196 - 121ms/epoch - 2ms/step
# Epoch 203/400
# 70/70 - 0s - loss: 1.8113 - accuracy: 0.4191 - 123ms/epoch - 2ms/step
# Epoch 204/400
# 70/70 - 0s - loss: 1.8102 - accuracy: 0.4223 - 120ms/epoch - 2ms/step
# Epoch 205/400
# 70/70 - 0s - loss: 1.8089 - accuracy: 0.4169 - 123ms/epoch - 2ms/step
# Epoch 206/400
# 70/70 - 0s - loss: 1.8077 - accuracy: 0.4173 - 123ms/epoch - 2ms/step
# Epoch 207/400
# 70/70 - 0s - loss: 1.8068 - accuracy: 0.4316 - 122ms/epoch - 2ms/step
# Epoch 208/400
# 70/70 - 0s - loss: 1.8059 - accuracy: 0.4223 - 122ms/epoch - 2ms/step
# Epoch 209/400
# 70/70 - 0s - loss: 1.8048 - accuracy: 0.4218 - 124ms/epoch - 2ms/step
# Epoch 210/400
# 70/70 - 0s - loss: 1.8038 - accuracy: 0.4236 - 122ms/epoch - 2ms/step
# Epoch 211/400
# 70/70 - 0s - loss: 1.8020 - accuracy: 0.4187 - 123ms/epoch - 2ms/step
# Epoch 212/400
# 70/70 - 0s - loss: 1.8026 - accuracy: 0.4231 - 120ms/epoch - 2ms/step
# Epoch 213/400
# 70/70 - 0s - loss: 1.8005 - accuracy: 0.4209 - 123ms/epoch - 2ms/step
# Epoch 214/400
# 70/70 - 0s - loss: 1.8004 - accuracy: 0.4200 - 124ms/epoch - 2ms/step
# Epoch 215/400
# 70/70 - 0s - loss: 1.7989 - accuracy: 0.4196 - 121ms/epoch - 2ms/step
# Epoch 216/400
# 70/70 - 0s - loss: 1.7977 - accuracy: 0.4240 - 122ms/epoch - 2ms/step
# Epoch 217/400
# 70/70 - 0s - loss: 1.7973 - accuracy: 0.4200 - 121ms/epoch - 2ms/step
# Epoch 218/400
# 70/70 - 0s - loss: 1.7961 - accuracy: 0.4187 - 123ms/epoch - 2ms/step
# Epoch 219/400
# 70/70 - 0s - loss: 1.7951 - accuracy: 0.4151 - 123ms/epoch - 2ms/step
# Epoch 220/400
# 70/70 - 0s - loss: 1.7946 - accuracy: 0.4164 - 121ms/epoch - 2ms/step
# Epoch 221/400
# 70/70 - 0s - loss: 1.7931 - accuracy: 0.4218 - 123ms/epoch - 2ms/step
# Epoch 222/400
# 70/70 - 0s - loss: 1.7919 - accuracy: 0.4223 - 126ms/epoch - 2ms/step
# Epoch 223/400
# 70/70 - 0s - loss: 1.7915 - accuracy: 0.4281 - 121ms/epoch - 2ms/step
# Epoch 224/400
# 70/70 - 0s - loss: 1.7923 - accuracy: 0.4191 - 123ms/epoch - 2ms/step
# Epoch 225/400
# 70/70 - 0s - loss: 1.7894 - accuracy: 0.4240 - 121ms/epoch - 2ms/step
# Epoch 226/400
# 70/70 - 0s - loss: 1.7897 - accuracy: 0.4187 - 121ms/epoch - 2ms/step
# Epoch 227/400
# 70/70 - 0s - loss: 1.7884 - accuracy: 0.4214 - 121ms/epoch - 2ms/step
# Epoch 228/400
# 70/70 - 0s - loss: 1.7861 - accuracy: 0.4231 - 139ms/epoch - 2ms/step
# Epoch 229/400
# 70/70 - 0s - loss: 1.7865 - accuracy: 0.4196 - 124ms/epoch - 2ms/step
# Epoch 230/400
# 70/70 - 0s - loss: 1.7873 - accuracy: 0.4182 - 139ms/epoch - 2ms/step
# Epoch 231/400
# 70/70 - 0s - loss: 1.7844 - accuracy: 0.4187 - 123ms/epoch - 2ms/step
# Epoch 232/400
# 70/70 - 0s - loss: 1.7840 - accuracy: 0.4187 - 120ms/epoch - 2ms/step
# Epoch 233/400
# 70/70 - 0s - loss: 1.7845 - accuracy: 0.4209 - 122ms/epoch - 2ms/step
# Epoch 234/400
# 70/70 - 0s - loss: 1.7827 - accuracy: 0.4178 - 122ms/epoch - 2ms/step
# Epoch 235/400
# 70/70 - 0s - loss: 1.7824 - accuracy: 0.4214 - 122ms/epoch - 2ms/step
# Epoch 236/400
# 70/70 - 0s - loss: 1.7827 - accuracy: 0.4173 - 134ms/epoch - 2ms/step
# Epoch 237/400
# 70/70 - 0s - loss: 1.7815 - accuracy: 0.4147 - 122ms/epoch - 2ms/step
# Epoch 238/400
# 70/70 - 0s - loss: 1.7804 - accuracy: 0.4200 - 124ms/epoch - 2ms/step
# Epoch 239/400
# 70/70 - 0s - loss: 1.7795 - accuracy: 0.4187 - 120ms/epoch - 2ms/step
# Epoch 240/400
# 70/70 - 0s - loss: 1.7804 - accuracy: 0.4164 - 120ms/epoch - 2ms/step
# Epoch 241/400
# 70/70 - 0s - loss: 1.7785 - accuracy: 0.4115 - 124ms/epoch - 2ms/step
# Epoch 242/400
# 70/70 - 0s - loss: 1.7780 - accuracy: 0.4142 - 133ms/epoch - 2ms/step
# Epoch 243/400
# 70/70 - 0s - loss: 1.7769 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 244/400
# 70/70 - 0s - loss: 1.7759 - accuracy: 0.4200 - 121ms/epoch - 2ms/step
# Epoch 245/400
# 70/70 - 0s - loss: 1.7761 - accuracy: 0.4245 - 124ms/epoch - 2ms/step
# Epoch 246/400
# 70/70 - 0s - loss: 1.7766 - accuracy: 0.4191 - 125ms/epoch - 2ms/step
# Epoch 247/400
# 70/70 - 0s - loss: 1.7738 - accuracy: 0.4173 - 123ms/epoch - 2ms/step
# Epoch 248/400
# 70/70 - 0s - loss: 1.7745 - accuracy: 0.4129 - 122ms/epoch - 2ms/step
# Epoch 249/400
# 70/70 - 0s - loss: 1.7731 - accuracy: 0.4245 - 122ms/epoch - 2ms/step
# Epoch 250/400
# 70/70 - 0s - loss: 1.7724 - accuracy: 0.4182 - 121ms/epoch - 2ms/step
# Epoch 251/400
# 70/70 - 0s - loss: 1.7720 - accuracy: 0.4263 - 120ms/epoch - 2ms/step
# Epoch 252/400
# 70/70 - 0s - loss: 1.7705 - accuracy: 0.4151 - 122ms/epoch - 2ms/step
# Epoch 253/400
# 70/70 - 0s - loss: 1.7725 - accuracy: 0.4196 - 122ms/epoch - 2ms/step
# Epoch 254/400
# 70/70 - 0s - loss: 1.7707 - accuracy: 0.4200 - 123ms/epoch - 2ms/step
# Epoch 255/400
# 70/70 - 0s - loss: 1.7707 - accuracy: 0.4160 - 122ms/epoch - 2ms/step
# Epoch 256/400
# 70/70 - 0s - loss: 1.7701 - accuracy: 0.4191 - 121ms/epoch - 2ms/step
# Epoch 257/400
# 70/70 - 0s - loss: 1.7684 - accuracy: 0.4151 - 119ms/epoch - 2ms/step
# Epoch 258/400
# 70/70 - 0s - loss: 1.7678 - accuracy: 0.4160 - 122ms/epoch - 2ms/step
# Epoch 259/400
# 70/70 - 0s - loss: 1.7691 - accuracy: 0.4133 - 121ms/epoch - 2ms/step
# Epoch 260/400
# 70/70 - 0s - loss: 1.7665 - accuracy: 0.4160 - 122ms/epoch - 2ms/step
# Epoch 261/400
# 70/70 - 0s - loss: 1.7669 - accuracy: 0.4223 - 126ms/epoch - 2ms/step
# Epoch 262/400
# 70/70 - 0s - loss: 1.7672 - accuracy: 0.4182 - 139ms/epoch - 2ms/step
# Epoch 263/400
# 70/70 - 0s - loss: 1.7669 - accuracy: 0.4178 - 121ms/epoch - 2ms/step
# Epoch 264/400
# 70/70 - 0s - loss: 1.7668 - accuracy: 0.4178 - 122ms/epoch - 2ms/step
# Epoch 265/400
# 70/70 - 0s - loss: 1.7666 - accuracy: 0.4191 - 121ms/epoch - 2ms/step
# Epoch 266/400
# 70/70 - 0s - loss: 1.7649 - accuracy: 0.4178 - 122ms/epoch - 2ms/step
# Epoch 267/400
# 70/70 - 0s - loss: 1.7646 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 268/400
# 70/70 - 0s - loss: 1.7625 - accuracy: 0.4191 - 122ms/epoch - 2ms/step
# Epoch 269/400
# 70/70 - 0s - loss: 1.7634 - accuracy: 0.4191 - 121ms/epoch - 2ms/step
# Epoch 270/400
# 70/70 - 0s - loss: 1.7626 - accuracy: 0.4245 - 124ms/epoch - 2ms/step
# Epoch 271/400
# 70/70 - 0s - loss: 1.7621 - accuracy: 0.4151 - 122ms/epoch - 2ms/step
# Epoch 272/400
# 70/70 - 0s - loss: 1.7618 - accuracy: 0.4178 - 121ms/epoch - 2ms/step
# Epoch 273/400
# 70/70 - 0s - loss: 1.7614 - accuracy: 0.4178 - 123ms/epoch - 2ms/step
# Epoch 274/400
# 70/70 - 0s - loss: 1.7603 - accuracy: 0.4173 - 123ms/epoch - 2ms/step
# Epoch 275/400
# 70/70 - 0s - loss: 1.7608 - accuracy: 0.4151 - 121ms/epoch - 2ms/step
# Epoch 276/400
# 70/70 - 0s - loss: 1.7614 - accuracy: 0.4169 - 123ms/epoch - 2ms/step
# Epoch 277/400
# 70/70 - 0s - loss: 1.7611 - accuracy: 0.4124 - 124ms/epoch - 2ms/step
# Epoch 278/400
# 70/70 - 0s - loss: 1.7606 - accuracy: 0.4164 - 121ms/epoch - 2ms/step
# Epoch 279/400
# 70/70 - 0s - loss: 1.7593 - accuracy: 0.4187 - 127ms/epoch - 2ms/step
# Epoch 280/400
# 70/70 - 0s - loss: 1.7597 - accuracy: 0.4147 - 124ms/epoch - 2ms/step
# Epoch 281/400
# 70/70 - 0s - loss: 1.7577 - accuracy: 0.4155 - 122ms/epoch - 2ms/step
# Epoch 282/400
# 70/70 - 0s - loss: 1.7585 - accuracy: 0.4155 - 121ms/epoch - 2ms/step
# Epoch 283/400
# 70/70 - 0s - loss: 1.7575 - accuracy: 0.4151 - 122ms/epoch - 2ms/step
# Epoch 284/400
# 70/70 - 0s - loss: 1.7585 - accuracy: 0.4218 - 122ms/epoch - 2ms/step
# Epoch 285/400
# 70/70 - 0s - loss: 1.7574 - accuracy: 0.4151 - 121ms/epoch - 2ms/step
# Epoch 286/400
# 70/70 - 0s - loss: 1.7580 - accuracy: 0.4142 - 123ms/epoch - 2ms/step
# Epoch 287/400
# 70/70 - 0s - loss: 1.7578 - accuracy: 0.4111 - 126ms/epoch - 2ms/step
# Epoch 288/400
# 70/70 - 0s - loss: 1.7561 - accuracy: 0.4200 - 122ms/epoch - 2ms/step
# Epoch 289/400
# 70/70 - 0s - loss: 1.7556 - accuracy: 0.4111 - 122ms/epoch - 2ms/step
# Epoch 290/400
# 70/70 - 0s - loss: 1.7559 - accuracy: 0.4097 - 121ms/epoch - 2ms/step
# Epoch 291/400
# 70/70 - 0s - loss: 1.7556 - accuracy: 0.4164 - 124ms/epoch - 2ms/step
# Epoch 292/400
# 70/70 - 0s - loss: 1.7547 - accuracy: 0.4196 - 122ms/epoch - 2ms/step
# Epoch 293/400
# 70/70 - 0s - loss: 1.7534 - accuracy: 0.4160 - 123ms/epoch - 2ms/step
# Epoch 294/400
# 70/70 - 0s - loss: 1.7541 - accuracy: 0.4151 - 121ms/epoch - 2ms/step
# Epoch 295/400
# 70/70 - 0s - loss: 1.7527 - accuracy: 0.4182 - 142ms/epoch - 2ms/step
# Epoch 296/400
# 70/70 - 0s - loss: 1.7541 - accuracy: 0.4169 - 122ms/epoch - 2ms/step
# Epoch 297/400
# 70/70 - 0s - loss: 1.7536 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 298/400
# 70/70 - 0s - loss: 1.7520 - accuracy: 0.4115 - 121ms/epoch - 2ms/step
# Epoch 299/400
# 70/70 - 0s - loss: 1.7514 - accuracy: 0.4160 - 122ms/epoch - 2ms/step
# Epoch 300/400
# 70/70 - 0s - loss: 1.7531 - accuracy: 0.4187 - 121ms/epoch - 2ms/step
# Epoch 301/400
# 70/70 - 0s - loss: 1.7516 - accuracy: 0.4182 - 122ms/epoch - 2ms/step
# Epoch 302/400
# 70/70 - 0s - loss: 1.7514 - accuracy: 0.4205 - 121ms/epoch - 2ms/step
# Epoch 303/400
# 70/70 - 0s - loss: 1.7514 - accuracy: 0.4129 - 122ms/epoch - 2ms/step
# Epoch 304/400
# 70/70 - 0s - loss: 1.7510 - accuracy: 0.4218 - 123ms/epoch - 2ms/step
# Epoch 305/400
# 70/70 - 0s - loss: 1.7498 - accuracy: 0.4169 - 123ms/epoch - 2ms/step
# Epoch 306/400
# 70/70 - 0s - loss: 1.7500 - accuracy: 0.4200 - 121ms/epoch - 2ms/step
# Epoch 307/400
# 70/70 - 0s - loss: 1.7500 - accuracy: 0.4182 - 121ms/epoch - 2ms/step
# Epoch 308/400
# 70/70 - 0s - loss: 1.7507 - accuracy: 0.4218 - 121ms/epoch - 2ms/step
# Epoch 309/400
# 70/70 - 0s - loss: 1.7497 - accuracy: 0.4160 - 122ms/epoch - 2ms/step
# Epoch 310/400
# 70/70 - 0s - loss: 1.7490 - accuracy: 0.4164 - 123ms/epoch - 2ms/step
# Epoch 311/400
# 70/70 - 0s - loss: 1.7493 - accuracy: 0.4173 - 126ms/epoch - 2ms/step
# Epoch 312/400
# 70/70 - 0s - loss: 1.7485 - accuracy: 0.4187 - 121ms/epoch - 2ms/step
# Epoch 313/400
# 70/70 - 0s - loss: 1.7480 - accuracy: 0.4169 - 120ms/epoch - 2ms/step
# Epoch 314/400
# 70/70 - 0s - loss: 1.7488 - accuracy: 0.4124 - 120ms/epoch - 2ms/step
# Epoch 315/400
# 70/70 - 0s - loss: 1.7478 - accuracy: 0.4133 - 120ms/epoch - 2ms/step
# Epoch 316/400
# 70/70 - 0s - loss: 1.7482 - accuracy: 0.4133 - 120ms/epoch - 2ms/step
# Epoch 317/400
# 70/70 - 0s - loss: 1.7465 - accuracy: 0.4173 - 121ms/epoch - 2ms/step
# Epoch 318/400
# 70/70 - 0s - loss: 1.7474 - accuracy: 0.4196 - 120ms/epoch - 2ms/step
# Epoch 319/400
# 70/70 - 0s - loss: 1.7474 - accuracy: 0.4200 - 127ms/epoch - 2ms/step
# Epoch 320/400
# 70/70 - 0s - loss: 1.7461 - accuracy: 0.4142 - 120ms/epoch - 2ms/step
# Epoch 321/400
# 70/70 - 0s - loss: 1.7457 - accuracy: 0.4169 - 122ms/epoch - 2ms/step
# Epoch 322/400
# 70/70 - 0s - loss: 1.7454 - accuracy: 0.4160 - 121ms/epoch - 2ms/step
# Epoch 323/400
# 70/70 - 0s - loss: 1.7458 - accuracy: 0.4111 - 121ms/epoch - 2ms/step
# Epoch 324/400
# 70/70 - 0s - loss: 1.7451 - accuracy: 0.4142 - 121ms/epoch - 2ms/step
# Epoch 325/400
# 70/70 - 0s - loss: 1.7449 - accuracy: 0.4147 - 126ms/epoch - 2ms/step
# Epoch 326/400
# 70/70 - 0s - loss: 1.7446 - accuracy: 0.4227 - 121ms/epoch - 2ms/step
# Epoch 327/400
# 70/70 - 0s - loss: 1.7449 - accuracy: 0.4138 - 125ms/epoch - 2ms/step
# Epoch 328/400
# 70/70 - 0s - loss: 1.7457 - accuracy: 0.4155 - 135ms/epoch - 2ms/step
# Epoch 329/400
# 70/70 - 0s - loss: 1.7444 - accuracy: 0.4129 - 122ms/epoch - 2ms/step
# Epoch 330/400
# 70/70 - 0s - loss: 1.7443 - accuracy: 0.4147 - 123ms/epoch - 2ms/step
# Epoch 331/400
# 70/70 - 0s - loss: 1.7445 - accuracy: 0.4124 - 120ms/epoch - 2ms/step
# Epoch 332/400
# 70/70 - 0s - loss: 1.7441 - accuracy: 0.4142 - 121ms/epoch - 2ms/step
# Epoch 333/400
# 70/70 - 0s - loss: 1.7431 - accuracy: 0.4173 - 122ms/epoch - 2ms/step
# Epoch 334/400
# 70/70 - 0s - loss: 1.7439 - accuracy: 0.4133 - 128ms/epoch - 2ms/step
# Epoch 335/400
# 70/70 - 0s - loss: 1.7437 - accuracy: 0.4196 - 123ms/epoch - 2ms/step
# Epoch 336/400
# 70/70 - 0s - loss: 1.7446 - accuracy: 0.4115 - 120ms/epoch - 2ms/step
# Epoch 337/400
# 70/70 - 0s - loss: 1.7426 - accuracy: 0.4129 - 120ms/epoch - 2ms/step
# Epoch 338/400
# 70/70 - 0s - loss: 1.7436 - accuracy: 0.4138 - 121ms/epoch - 2ms/step
# Epoch 339/400
# 70/70 - 0s - loss: 1.7422 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 340/400
# 70/70 - 0s - loss: 1.7428 - accuracy: 0.4151 - 124ms/epoch - 2ms/step
# Epoch 341/400
# 70/70 - 0s - loss: 1.7422 - accuracy: 0.4138 - 121ms/epoch - 2ms/step
# Epoch 342/400
# 70/70 - 0s - loss: 1.7420 - accuracy: 0.4124 - 123ms/epoch - 2ms/step
# Epoch 343/400
# 70/70 - 0s - loss: 1.7416 - accuracy: 0.4124 - 127ms/epoch - 2ms/step
# Epoch 344/400
# 70/70 - 0s - loss: 1.7405 - accuracy: 0.4147 - 124ms/epoch - 2ms/step
# Epoch 345/400
# 70/70 - 0s - loss: 1.7409 - accuracy: 0.4191 - 121ms/epoch - 2ms/step
# Epoch 346/400
# 70/70 - 0s - loss: 1.7398 - accuracy: 0.4129 - 123ms/epoch - 2ms/step
# Epoch 347/400
# 70/70 - 0s - loss: 1.7410 - accuracy: 0.4178 - 122ms/epoch - 2ms/step
# Epoch 348/400
# 70/70 - 0s - loss: 1.7411 - accuracy: 0.4075 - 122ms/epoch - 2ms/step
# Epoch 349/400
# 70/70 - 0s - loss: 1.7393 - accuracy: 0.4142 - 121ms/epoch - 2ms/step
# Epoch 350/400
# 70/70 - 0s - loss: 1.7408 - accuracy: 0.4182 - 124ms/epoch - 2ms/step
# Epoch 351/400
# 70/70 - 0s - loss: 1.7386 - accuracy: 0.4169 - 126ms/epoch - 2ms/step
# Epoch 352/400
# 70/70 - 0s - loss: 1.7403 - accuracy: 0.4164 - 120ms/epoch - 2ms/step
# Epoch 353/400
# 70/70 - 0s - loss: 1.7400 - accuracy: 0.4124 - 122ms/epoch - 2ms/step
# Epoch 354/400
# 70/70 - 0s - loss: 1.7389 - accuracy: 0.4097 - 122ms/epoch - 2ms/step
# Epoch 355/400
# 70/70 - 0s - loss: 1.7405 - accuracy: 0.4155 - 122ms/epoch - 2ms/step
# Epoch 356/400
# 70/70 - 0s - loss: 1.7393 - accuracy: 0.4155 - 120ms/epoch - 2ms/step
# Epoch 357/400
# 70/70 - 0s - loss: 1.7390 - accuracy: 0.4178 - 125ms/epoch - 2ms/step
# Epoch 358/400
# 70/70 - 0s - loss: 1.7397 - accuracy: 0.4120 - 122ms/epoch - 2ms/step
# Epoch 359/400
# 70/70 - 0s - loss: 1.7381 - accuracy: 0.4191 - 124ms/epoch - 2ms/step
# Epoch 360/400
# 70/70 - 0s - loss: 1.7383 - accuracy: 0.4129 - 135ms/epoch - 2ms/step
# Epoch 361/400
# 70/70 - 0s - loss: 1.7381 - accuracy: 0.4178 - 121ms/epoch - 2ms/step
# Epoch 362/400
# 70/70 - 0s - loss: 1.7377 - accuracy: 0.4173 - 120ms/epoch - 2ms/step
# Epoch 363/400
# 70/70 - 0s - loss: 1.7382 - accuracy: 0.4160 - 121ms/epoch - 2ms/step
# Epoch 364/400
# 70/70 - 0s - loss: 1.7375 - accuracy: 0.4151 - 121ms/epoch - 2ms/step
# Epoch 365/400
# 70/70 - 0s - loss: 1.7361 - accuracy: 0.4124 - 123ms/epoch - 2ms/step
# Epoch 366/400
# 70/70 - 0s - loss: 1.7360 - accuracy: 0.4111 - 121ms/epoch - 2ms/step
# Epoch 367/400
# 70/70 - 0s - loss: 1.7368 - accuracy: 0.4133 - 126ms/epoch - 2ms/step
# Epoch 368/400
# 70/70 - 0s - loss: 1.7371 - accuracy: 0.4178 - 126ms/epoch - 2ms/step
# Epoch 369/400
# 70/70 - 0s - loss: 1.7369 - accuracy: 0.4182 - 123ms/epoch - 2ms/step
# Epoch 370/400
# 70/70 - 0s - loss: 1.7362 - accuracy: 0.4151 - 120ms/epoch - 2ms/step
# Epoch 371/400
# 70/70 - 0s - loss: 1.7364 - accuracy: 0.4142 - 121ms/epoch - 2ms/step
# Epoch 372/400
# 70/70 - 0s - loss: 1.7366 - accuracy: 0.4111 - 121ms/epoch - 2ms/step
# Epoch 373/400
# 70/70 - 0s - loss: 1.7362 - accuracy: 0.4111 - 122ms/epoch - 2ms/step
# Epoch 374/400
# 70/70 - 0s - loss: 1.7365 - accuracy: 0.4182 - 122ms/epoch - 2ms/step
# Epoch 375/400
# 70/70 - 0s - loss: 1.7360 - accuracy: 0.4124 - 123ms/epoch - 2ms/step
# Epoch 376/400
# 70/70 - 0s - loss: 1.7359 - accuracy: 0.4129 - 124ms/epoch - 2ms/step
# Epoch 377/400
# 70/70 - 0s - loss: 1.7347 - accuracy: 0.4097 - 121ms/epoch - 2ms/step
# Epoch 378/400
# 70/70 - 0s - loss: 1.7346 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 379/400
# 70/70 - 0s - loss: 1.7359 - accuracy: 0.4160 - 121ms/epoch - 2ms/step
# Epoch 380/400
# 70/70 - 0s - loss: 1.7351 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 381/400
# 70/70 - 0s - loss: 1.7341 - accuracy: 0.4075 - 123ms/epoch - 2ms/step
# Epoch 382/400
# 70/70 - 0s - loss: 1.7339 - accuracy: 0.4169 - 122ms/epoch - 2ms/step
# Epoch 383/400
# 70/70 - 0s - loss: 1.7350 - accuracy: 0.4147 - 121ms/epoch - 2ms/step
# Epoch 384/400
# 70/70 - 0s - loss: 1.7334 - accuracy: 0.4115 - 124ms/epoch - 2ms/step
# Epoch 385/400
# 70/70 - 0s - loss: 1.7349 - accuracy: 0.4200 - 122ms/epoch - 2ms/step
# Epoch 386/400
# 70/70 - 0s - loss: 1.7333 - accuracy: 0.4160 - 125ms/epoch - 2ms/step
# Epoch 387/400
# 70/70 - 0s - loss: 1.7331 - accuracy: 0.4187 - 120ms/epoch - 2ms/step
# Epoch 388/400
# 70/70 - 0s - loss: 1.7343 - accuracy: 0.4115 - 121ms/epoch - 2ms/step
# Epoch 389/400
# 70/70 - 0s - loss: 1.7331 - accuracy: 0.4155 - 121ms/epoch - 2ms/step
# Epoch 390/400
# 70/70 - 0s - loss: 1.7344 - accuracy: 0.4160 - 121ms/epoch - 2ms/step
# Epoch 391/400
# 70/70 - 0s - loss: 1.7332 - accuracy: 0.4147 - 122ms/epoch - 2ms/step
# Epoch 392/400
# 70/70 - 0s - loss: 1.7329 - accuracy: 0.4182 - 124ms/epoch - 2ms/step
# Epoch 393/400
# 70/70 - 0s - loss: 1.7340 - accuracy: 0.4111 - 138ms/epoch - 2ms/step
# Epoch 394/400
# 70/70 - 0s - loss: 1.7339 - accuracy: 0.4205 - 123ms/epoch - 2ms/step
# Epoch 395/400
# 70/70 - 0s - loss: 1.7336 - accuracy: 0.4142 - 120ms/epoch - 2ms/step
# Epoch 396/400
# 70/70 - 0s - loss: 1.7324 - accuracy: 0.4133 - 122ms/epoch - 2ms/step
# Epoch 397/400
# 70/70 - 0s - loss: 1.7331 - accuracy: 0.4124 - 123ms/epoch - 2ms/step
# Epoch 398/400
# 70/70 - 0s - loss: 1.7319 - accuracy: 0.4182 - 122ms/epoch - 2ms/step
# Epoch 399/400
# 70/70 - 0s - loss: 1.7323 - accuracy: 0.4160 - 124ms/epoch - 2ms/step
# Epoch 400/400
# 70/70 - 0s - loss: 1.7326 - accuracy: 0.4142 - 125ms/epoch - 2ms/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 2, 10)             9050
#
#  lstm_3 (LSTM)               (None, 50)                12200
#
#  dense_3 (Dense)             (None, 905)               46155
#
# =================================================================
# Total params: 67405 (263.30 KB)
# Trainable params: 67405 (263.30 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/400
# 70/70 - 2s - loss: 6.7874 - accuracy: 0.0425 - 2s/epoch - 23ms/step
# Epoch 2/400
# 70/70 - 0s - loss: 6.4320 - accuracy: 0.0532 - 147ms/epoch - 2ms/step
# Epoch 3/400
# 70/70 - 0s - loss: 5.9577 - accuracy: 0.0532 - 138ms/epoch - 2ms/step
# Epoch 4/400
# 70/70 - 0s - loss: 5.8856 - accuracy: 0.0532 - 139ms/epoch - 2ms/step
# Epoch 5/400
# 70/70 - 0s - loss: 5.8337 - accuracy: 0.0532 - 142ms/epoch - 2ms/step
# Epoch 6/400
# 70/70 - 0s - loss: 5.7823 - accuracy: 0.0532 - 139ms/epoch - 2ms/step
# Epoch 7/400
# 70/70 - 0s - loss: 5.7368 - accuracy: 0.0532 - 139ms/epoch - 2ms/step
# Epoch 8/400
# 70/70 - 0s - loss: 5.7007 - accuracy: 0.0532 - 138ms/epoch - 2ms/step
# Epoch 9/400
# 70/70 - 0s - loss: 5.6706 - accuracy: 0.0536 - 142ms/epoch - 2ms/step
# Epoch 10/400
# 70/70 - 0s - loss: 5.6426 - accuracy: 0.0536 - 138ms/epoch - 2ms/step
# Epoch 11/400
# 70/70 - 0s - loss: 5.6183 - accuracy: 0.0532 - 139ms/epoch - 2ms/step
# Epoch 12/400
# 70/70 - 0s - loss: 5.5973 - accuracy: 0.0541 - 139ms/epoch - 2ms/step
# Epoch 13/400
# 70/70 - 0s - loss: 5.5754 - accuracy: 0.0536 - 138ms/epoch - 2ms/step
# Epoch 14/400
# 70/70 - 0s - loss: 5.5547 - accuracy: 0.0541 - 140ms/epoch - 2ms/step
# Epoch 15/400
# 70/70 - 0s - loss: 5.5345 - accuracy: 0.0536 - 137ms/epoch - 2ms/step
# Epoch 16/400
# 70/70 - 0s - loss: 5.5134 - accuracy: 0.0541 - 143ms/epoch - 2ms/step
# Epoch 17/400
# 70/70 - 0s - loss: 5.4941 - accuracy: 0.0581 - 154ms/epoch - 2ms/step
# Epoch 18/400
# 70/70 - 0s - loss: 5.4722 - accuracy: 0.0541 - 140ms/epoch - 2ms/step
# Epoch 19/400
# 70/70 - 0s - loss: 5.4512 - accuracy: 0.0545 - 139ms/epoch - 2ms/step
# Epoch 20/400
# 70/70 - 0s - loss: 5.4302 - accuracy: 0.0536 - 138ms/epoch - 2ms/step
# Epoch 21/400
# 70/70 - 0s - loss: 5.4090 - accuracy: 0.0554 - 140ms/epoch - 2ms/step
# Epoch 22/400
# 70/70 - 0s - loss: 5.3892 - accuracy: 0.0545 - 140ms/epoch - 2ms/step
# Epoch 23/400
# 70/70 - 0s - loss: 5.3688 - accuracy: 0.0554 - 142ms/epoch - 2ms/step
# Epoch 24/400
# 70/70 - 0s - loss: 5.3478 - accuracy: 0.0568 - 141ms/epoch - 2ms/step
# Epoch 25/400
# 70/70 - 0s - loss: 5.3267 - accuracy: 0.0572 - 139ms/epoch - 2ms/step
# Epoch 26/400
# 70/70 - 0s - loss: 5.3040 - accuracy: 0.0599 - 141ms/epoch - 2ms/step
# Epoch 27/400
# 70/70 - 0s - loss: 5.2798 - accuracy: 0.0595 - 139ms/epoch - 2ms/step
# Epoch 28/400
# 70/70 - 0s - loss: 5.2566 - accuracy: 0.0577 - 140ms/epoch - 2ms/step
# Epoch 29/400
# 70/70 - 0s - loss: 5.2312 - accuracy: 0.0612 - 140ms/epoch - 2ms/step
# Epoch 30/400
# 70/70 - 0s - loss: 5.2067 - accuracy: 0.0599 - 148ms/epoch - 2ms/step
# Epoch 31/400
# 70/70 - 0s - loss: 5.1756 - accuracy: 0.0608 - 137ms/epoch - 2ms/step
# Epoch 32/400
# 70/70 - 0s - loss: 5.1431 - accuracy: 0.0608 - 138ms/epoch - 2ms/step
# Epoch 33/400
# 70/70 - 0s - loss: 5.1074 - accuracy: 0.0626 - 139ms/epoch - 2ms/step
# Epoch 34/400
# 70/70 - 0s - loss: 5.0682 - accuracy: 0.0657 - 138ms/epoch - 2ms/step
# Epoch 35/400
# 70/70 - 0s - loss: 5.0249 - accuracy: 0.0657 - 140ms/epoch - 2ms/step
# Epoch 36/400
# 70/70 - 0s - loss: 4.9764 - accuracy: 0.0653 - 138ms/epoch - 2ms/step
# Epoch 37/400
# 70/70 - 0s - loss: 4.9256 - accuracy: 0.0675 - 143ms/epoch - 2ms/step
# Epoch 38/400
# 70/70 - 0s - loss: 4.8713 - accuracy: 0.0738 - 139ms/epoch - 2ms/step
# Epoch 39/400
# 70/70 - 0s - loss: 4.8210 - accuracy: 0.0787 - 138ms/epoch - 2ms/step
# Epoch 40/400
# 70/70 - 0s - loss: 4.7669 - accuracy: 0.0796 - 139ms/epoch - 2ms/step
# Epoch 41/400
# 70/70 - 0s - loss: 4.7129 - accuracy: 0.0823 - 138ms/epoch - 2ms/step
# Epoch 42/400
# 70/70 - 0s - loss: 4.6599 - accuracy: 0.0854 - 140ms/epoch - 2ms/step
# Epoch 43/400
# 70/70 - 0s - loss: 4.6077 - accuracy: 0.0925 - 141ms/epoch - 2ms/step
# Epoch 44/400
# 70/70 - 0s - loss: 4.5551 - accuracy: 0.0934 - 140ms/epoch - 2ms/step
# Epoch 45/400
# 70/70 - 0s - loss: 4.5056 - accuracy: 0.0988 - 138ms/epoch - 2ms/step
# Epoch 46/400
# 70/70 - 0s - loss: 4.4551 - accuracy: 0.1010 - 140ms/epoch - 2ms/step
# Epoch 47/400
# 70/70 - 0s - loss: 4.4038 - accuracy: 0.1073 - 139ms/epoch - 2ms/step
# Epoch 48/400
# 70/70 - 0s - loss: 4.3565 - accuracy: 0.1135 - 139ms/epoch - 2ms/step
# Epoch 49/400
# 70/70 - 0s - loss: 4.3085 - accuracy: 0.1162 - 139ms/epoch - 2ms/step
# Epoch 50/400
# 70/70 - 0s - loss: 4.2603 - accuracy: 0.1238 - 156ms/epoch - 2ms/step
# Epoch 51/400
# 70/70 - 0s - loss: 4.2123 - accuracy: 0.1225 - 143ms/epoch - 2ms/step
# Epoch 52/400
# 70/70 - 0s - loss: 4.1673 - accuracy: 0.1314 - 141ms/epoch - 2ms/step
# Epoch 53/400
# 70/70 - 0s - loss: 4.1220 - accuracy: 0.1354 - 140ms/epoch - 2ms/step
# Epoch 54/400
# 70/70 - 0s - loss: 4.0768 - accuracy: 0.1337 - 144ms/epoch - 2ms/step
# Epoch 55/400
# 70/70 - 0s - loss: 4.0313 - accuracy: 0.1484 - 138ms/epoch - 2ms/step
# Epoch 56/400
# 70/70 - 0s - loss: 3.9890 - accuracy: 0.1480 - 139ms/epoch - 2ms/step
# Epoch 57/400
# 70/70 - 0s - loss: 3.9443 - accuracy: 0.1556 - 139ms/epoch - 2ms/step
# Epoch 58/400
# 70/70 - 0s - loss: 3.9005 - accuracy: 0.1658 - 142ms/epoch - 2ms/step
# Epoch 59/400
# 70/70 - 0s - loss: 3.8591 - accuracy: 0.1708 - 138ms/epoch - 2ms/step
# Epoch 60/400
# 70/70 - 0s - loss: 3.8160 - accuracy: 0.1681 - 140ms/epoch - 2ms/step
# Epoch 61/400
# 70/70 - 0s - loss: 3.7725 - accuracy: 0.1810 - 137ms/epoch - 2ms/step
# Epoch 62/400
# 70/70 - 0s - loss: 3.7333 - accuracy: 0.1828 - 139ms/epoch - 2ms/step
# Epoch 63/400
# 70/70 - 0s - loss: 3.6918 - accuracy: 0.1954 - 139ms/epoch - 2ms/step
# Epoch 64/400
# 70/70 - 0s - loss: 3.6526 - accuracy: 0.1954 - 140ms/epoch - 2ms/step
# Epoch 65/400
# 70/70 - 0s - loss: 3.6126 - accuracy: 0.2101 - 142ms/epoch - 2ms/step
# Epoch 66/400
# 70/70 - 0s - loss: 3.5688 - accuracy: 0.2119 - 139ms/epoch - 2ms/step
# Epoch 67/400
# 70/70 - 0s - loss: 3.5301 - accuracy: 0.2217 - 139ms/epoch - 2ms/step
# Epoch 68/400
# 70/70 - 0s - loss: 3.4906 - accuracy: 0.2302 - 138ms/epoch - 2ms/step
# Epoch 69/400
# 70/70 - 0s - loss: 3.4527 - accuracy: 0.2427 - 140ms/epoch - 2ms/step
# Epoch 70/400
# 70/70 - 0s - loss: 3.4157 - accuracy: 0.2521 - 139ms/epoch - 2ms/step
# Epoch 71/400
# 70/70 - 0s - loss: 3.3780 - accuracy: 0.2561 - 139ms/epoch - 2ms/step
# Epoch 72/400
# 70/70 - 0s - loss: 3.3390 - accuracy: 0.2620 - 142ms/epoch - 2ms/step
# Epoch 73/400
# 70/70 - 0s - loss: 3.3047 - accuracy: 0.2767 - 138ms/epoch - 2ms/step
# Epoch 74/400
# 70/70 - 0s - loss: 3.2662 - accuracy: 0.2830 - 140ms/epoch - 2ms/step
# Epoch 75/400
# 70/70 - 0s - loss: 3.2304 - accuracy: 0.2906 - 140ms/epoch - 2ms/step
# Epoch 76/400
# 70/70 - 0s - loss: 3.1952 - accuracy: 0.2910 - 137ms/epoch - 2ms/step
# Epoch 77/400
# 70/70 - 0s - loss: 3.1597 - accuracy: 0.3026 - 141ms/epoch - 2ms/step
# Epoch 78/400
# 70/70 - 0s - loss: 3.1251 - accuracy: 0.3116 - 139ms/epoch - 2ms/step
# Epoch 79/400
# 70/70 - 0s - loss: 3.0905 - accuracy: 0.3107 - 140ms/epoch - 2ms/step
# Epoch 80/400
# 70/70 - 0s - loss: 3.0560 - accuracy: 0.3232 - 143ms/epoch - 2ms/step
# Epoch 81/400
# 70/70 - 0s - loss: 3.0228 - accuracy: 0.3254 - 154ms/epoch - 2ms/step
# Epoch 82/400
# 70/70 - 0s - loss: 2.9889 - accuracy: 0.3295 - 140ms/epoch - 2ms/step
# Epoch 83/400
# 70/70 - 0s - loss: 2.9590 - accuracy: 0.3433 - 139ms/epoch - 2ms/step
# Epoch 84/400
# 70/70 - 0s - loss: 2.9241 - accuracy: 0.3487 - 140ms/epoch - 2ms/step
# Epoch 85/400
# 70/70 - 0s - loss: 2.8928 - accuracy: 0.3603 - 139ms/epoch - 2ms/step
# Epoch 86/400
# 70/70 - 0s - loss: 2.8603 - accuracy: 0.3675 - 141ms/epoch - 2ms/step
# Epoch 87/400
# 70/70 - 0s - loss: 2.8289 - accuracy: 0.3773 - 141ms/epoch - 2ms/step
# Epoch 88/400
# 70/70 - 0s - loss: 2.8005 - accuracy: 0.3782 - 139ms/epoch - 2ms/step
# Epoch 89/400
# 70/70 - 0s - loss: 2.7680 - accuracy: 0.3844 - 140ms/epoch - 2ms/step
# Epoch 90/400
# 70/70 - 0s - loss: 2.7398 - accuracy: 0.3920 - 138ms/epoch - 2ms/step
# Epoch 91/400
# 70/70 - 0s - loss: 2.7098 - accuracy: 0.4019 - 139ms/epoch - 2ms/step
# Epoch 92/400
# 70/70 - 0s - loss: 2.6823 - accuracy: 0.4077 - 139ms/epoch - 2ms/step
# Epoch 93/400
# 70/70 - 0s - loss: 2.6510 - accuracy: 0.4153 - 140ms/epoch - 2ms/step
# Epoch 94/400
# 70/70 - 0s - loss: 2.6223 - accuracy: 0.4274 - 142ms/epoch - 2ms/step
# Epoch 95/400
# 70/70 - 0s - loss: 2.5920 - accuracy: 0.4305 - 139ms/epoch - 2ms/step
# Epoch 96/400
# 70/70 - 0s - loss: 2.5672 - accuracy: 0.4426 - 138ms/epoch - 2ms/step
# Epoch 97/400
# 70/70 - 0s - loss: 2.5362 - accuracy: 0.4502 - 138ms/epoch - 2ms/step
# Epoch 98/400
# 70/70 - 0s - loss: 2.5075 - accuracy: 0.4582 - 139ms/epoch - 2ms/step
# Epoch 99/400
# 70/70 - 0s - loss: 2.4794 - accuracy: 0.4618 - 139ms/epoch - 2ms/step
# Epoch 100/400
# 70/70 - 0s - loss: 2.4526 - accuracy: 0.4747 - 139ms/epoch - 2ms/step
# Epoch 101/400
# 70/70 - 0s - loss: 2.4255 - accuracy: 0.4765 - 140ms/epoch - 2ms/step
# Epoch 102/400
# 70/70 - 0s - loss: 2.3974 - accuracy: 0.4774 - 137ms/epoch - 2ms/step
# Epoch 103/400
# 70/70 - 0s - loss: 2.3721 - accuracy: 0.4971 - 139ms/epoch - 2ms/step
# Epoch 104/400
# 70/70 - 0s - loss: 2.3467 - accuracy: 0.4949 - 138ms/epoch - 2ms/step
# Epoch 105/400
# 70/70 - 0s - loss: 2.3213 - accuracy: 0.5011 - 137ms/epoch - 2ms/step
# Epoch 106/400
# 70/70 - 0s - loss: 2.2938 - accuracy: 0.5114 - 139ms/epoch - 2ms/step
# Epoch 107/400
# 70/70 - 0s - loss: 2.2704 - accuracy: 0.5194 - 140ms/epoch - 2ms/step
# Epoch 108/400
# 70/70 - 0s - loss: 2.2447 - accuracy: 0.5217 - 141ms/epoch - 2ms/step
# Epoch 109/400
# 70/70 - 0s - loss: 2.2188 - accuracy: 0.5311 - 141ms/epoch - 2ms/step
# Epoch 110/400
# 70/70 - 0s - loss: 2.1947 - accuracy: 0.5382 - 139ms/epoch - 2ms/step
# Epoch 111/400
# 70/70 - 0s - loss: 2.1693 - accuracy: 0.5427 - 139ms/epoch - 2ms/step
# Epoch 112/400
# 70/70 - 0s - loss: 2.1476 - accuracy: 0.5489 - 153ms/epoch - 2ms/step
# Epoch 113/400
# 70/70 - 0s - loss: 2.1226 - accuracy: 0.5507 - 140ms/epoch - 2ms/step
# Epoch 114/400
# 70/70 - 0s - loss: 2.0967 - accuracy: 0.5646 - 139ms/epoch - 2ms/step
# Epoch 115/400
# 70/70 - 0s - loss: 2.0751 - accuracy: 0.5668 - 142ms/epoch - 2ms/step
# Epoch 116/400
# 70/70 - 0s - loss: 2.0512 - accuracy: 0.5758 - 140ms/epoch - 2ms/step
# Epoch 117/400
# 70/70 - 0s - loss: 2.0280 - accuracy: 0.5798 - 139ms/epoch - 2ms/step
# Epoch 118/400
# 70/70 - 0s - loss: 2.0059 - accuracy: 0.5945 - 138ms/epoch - 2ms/step
# Epoch 119/400
# 70/70 - 0s - loss: 1.9842 - accuracy: 0.5945 - 137ms/epoch - 2ms/step
# Epoch 120/400
# 70/70 - 0s - loss: 1.9606 - accuracy: 0.6017 - 139ms/epoch - 2ms/step
# Epoch 121/400
# 70/70 - 0s - loss: 1.9386 - accuracy: 0.6013 - 142ms/epoch - 2ms/step
# Epoch 122/400
# 70/70 - 0s - loss: 1.9164 - accuracy: 0.6120 - 141ms/epoch - 2ms/step
# Epoch 123/400
# 70/70 - 0s - loss: 1.8946 - accuracy: 0.6084 - 139ms/epoch - 2ms/step
# Epoch 124/400
# 70/70 - 0s - loss: 1.8724 - accuracy: 0.6191 - 138ms/epoch - 2ms/step
# Epoch 125/400
# 70/70 - 0s - loss: 1.8508 - accuracy: 0.6258 - 138ms/epoch - 2ms/step
# Epoch 126/400
# 70/70 - 0s - loss: 1.8302 - accuracy: 0.6343 - 139ms/epoch - 2ms/step
# Epoch 127/400
# 70/70 - 0s - loss: 1.8094 - accuracy: 0.6357 - 140ms/epoch - 2ms/step
# Epoch 128/400
# 70/70 - 0s - loss: 1.7883 - accuracy: 0.6428 - 138ms/epoch - 2ms/step
# Epoch 129/400
# 70/70 - 0s - loss: 1.7685 - accuracy: 0.6451 - 144ms/epoch - 2ms/step
# Epoch 130/400
# 70/70 - 0s - loss: 1.7487 - accuracy: 0.6410 - 138ms/epoch - 2ms/step
# Epoch 131/400
# 70/70 - 0s - loss: 1.7307 - accuracy: 0.6504 - 137ms/epoch - 2ms/step
# Epoch 132/400
# 70/70 - 0s - loss: 1.7080 - accuracy: 0.6616 - 139ms/epoch - 2ms/step
# Epoch 133/400
# 70/70 - 0s - loss: 1.6889 - accuracy: 0.6598 - 140ms/epoch - 2ms/step
# Epoch 134/400
# 70/70 - 0s - loss: 1.6703 - accuracy: 0.6679 - 138ms/epoch - 2ms/step
# Epoch 135/400
# 70/70 - 0s - loss: 1.6521 - accuracy: 0.6643 - 139ms/epoch - 2ms/step
# Epoch 136/400
# 70/70 - 0s - loss: 1.6322 - accuracy: 0.6741 - 144ms/epoch - 2ms/step
# Epoch 137/400
# 70/70 - 0s - loss: 1.6139 - accuracy: 0.6786 - 139ms/epoch - 2ms/step
# Epoch 138/400
# 70/70 - 0s - loss: 1.5955 - accuracy: 0.6804 - 138ms/epoch - 2ms/step
# Epoch 139/400
# 70/70 - 0s - loss: 1.5749 - accuracy: 0.6817 - 140ms/epoch - 2ms/step
# Epoch 140/400
# 70/70 - 0s - loss: 1.5588 - accuracy: 0.6929 - 139ms/epoch - 2ms/step
# Epoch 141/400
# 70/70 - 0s - loss: 1.5419 - accuracy: 0.6880 - 139ms/epoch - 2ms/step
# Epoch 142/400
# 70/70 - 0s - loss: 1.5236 - accuracy: 0.6951 - 158ms/epoch - 2ms/step
# Epoch 143/400
# 70/70 - 0s - loss: 1.5069 - accuracy: 0.6983 - 143ms/epoch - 2ms/step
# Epoch 144/400
# 70/70 - 0s - loss: 1.4906 - accuracy: 0.7009 - 138ms/epoch - 2ms/step
# Epoch 145/400
# 70/70 - 0s - loss: 1.4733 - accuracy: 0.7032 - 138ms/epoch - 2ms/step
# Epoch 146/400
# 70/70 - 0s - loss: 1.4547 - accuracy: 0.7000 - 138ms/epoch - 2ms/step
# Epoch 147/400
# 70/70 - 0s - loss: 1.4385 - accuracy: 0.7135 - 139ms/epoch - 2ms/step
# Epoch 148/400
# 70/70 - 0s - loss: 1.4241 - accuracy: 0.7117 - 138ms/epoch - 2ms/step
# Epoch 149/400
# 70/70 - 0s - loss: 1.4075 - accuracy: 0.7166 - 139ms/epoch - 2ms/step
# Epoch 150/400
# 70/70 - 0s - loss: 1.3921 - accuracy: 0.7215 - 139ms/epoch - 2ms/step
# Epoch 151/400
# 70/70 - 0s - loss: 1.3759 - accuracy: 0.7228 - 139ms/epoch - 2ms/step
# Epoch 152/400
# 70/70 - 0s - loss: 1.3603 - accuracy: 0.7260 - 138ms/epoch - 2ms/step
# Epoch 153/400
# 70/70 - 0s - loss: 1.3473 - accuracy: 0.7295 - 142ms/epoch - 2ms/step
# Epoch 154/400
# ...
# Epoch 211/400
# 70/70 - 0s - loss: 0.7217 - accuracy: 0.8257 - 140ms/epoch - 2ms/step
# Epoch 212/400
# 70/70 - 0s - loss: 0.7165 - accuracy: 0.8243 - 139ms/epoch - 2ms/step
# Epoch 213/400
# 70/70 - 0s - loss: 0.7086 - accuracy: 0.8274 - 139ms/epoch - 2ms/step
# Epoch 214/400
# 70/70 - 0s - loss: 0.7006 - accuracy: 0.8266 - 141ms/epoch - 2ms/step
# Epoch 215/400
# 70/70 - 0s - loss: 0.6944 - accuracy: 0.8301 - 141ms/epoch - 2ms/step
# Epoch 216/400
# 70/70 - 0s - loss: 0.6869 - accuracy: 0.8337 - 142ms/epoch - 2ms/step
# Epoch 217/400
# 70/70 - 0s - loss: 0.6793 - accuracy: 0.8373 - 138ms/epoch - 2ms/step
# Epoch 218/400
# 70/70 - 0s - loss: 0.6735 - accuracy: 0.8386 - 139ms/epoch - 2ms/step
# Epoch 219/400
# 70/70 - 0s - loss: 0.6670 - accuracy: 0.8373 - 138ms/epoch - 2ms/step
# Epoch 220/400
# 70/70 - 0s - loss: 0.6610 - accuracy: 0.8346 - 162ms/epoch - 2ms/step
# Epoch 221/400
# 70/70 - 0s - loss: 0.6559 - accuracy: 0.8368 - 154ms/epoch - 2ms/step
# Epoch 222/400
# 70/70 - 0s - loss: 0.6480 - accuracy: 0.8368 - 138ms/epoch - 2ms/step
# Epoch 223/400
# 70/70 - 0s - loss: 0.6421 - accuracy: 0.8382 - 138ms/epoch - 2ms/step
# Epoch 224/400
# 70/70 - 0s - loss: 0.6363 - accuracy: 0.8373 - 141ms/epoch - 2ms/step
# Epoch 225/400
# 70/70 - 0s - loss: 0.6292 - accuracy: 0.8418 - 138ms/epoch - 2ms/step
# Epoch 226/400
# 70/70 - 0s - loss: 0.6259 - accuracy: 0.8409 - 139ms/epoch - 2ms/step
# Epoch 227/400
# 70/70 - 0s - loss: 0.6175 - accuracy: 0.8431 - 139ms/epoch - 2ms/step
# Epoch 228/400
# 70/70 - 0s - loss: 0.6109 - accuracy: 0.8480 - 153ms/epoch - 2ms/step
# Epoch 229/400
# 70/70 - 0s - loss: 0.6055 - accuracy: 0.8435 - 156ms/epoch - 2ms/step
# Epoch 230/400
# 70/70 - 0s - loss: 0.6000 - accuracy: 0.8462 - 147ms/epoch - 2ms/step
# Epoch 231/400
# 70/70 - 0s - loss: 0.5950 - accuracy: 0.8418 - 149ms/epoch - 2ms/step
# Epoch 232/400
# 70/70 - 0s - loss: 0.5888 - accuracy: 0.8453 - 174ms/epoch - 2ms/step
# Epoch 233/400
# 70/70 - 0s - loss: 0.5840 - accuracy: 0.8502 - 157ms/epoch - 2ms/step
# Epoch 234/400
# 70/70 - 0s - loss: 0.5779 - accuracy: 0.8476 - 149ms/epoch - 2ms/step
# Epoch 235/400
# 70/70 - 0s - loss: 0.5738 - accuracy: 0.8444 - 147ms/epoch - 2ms/step
# Epoch 236/400
# 70/70 - 0s - loss: 0.5678 - accuracy: 0.8485 - 158ms/epoch - 2ms/step
# Epoch 237/400
# 70/70 - 0s - loss: 0.5632 - accuracy: 0.8502 - 146ms/epoch - 2ms/step
# Epoch 238/400
# 70/70 - 0s - loss: 0.5573 - accuracy: 0.8520 - 137ms/epoch - 2ms/step
# Epoch 239/400
# 70/70 - 0s - loss: 0.5513 - accuracy: 0.8520 - 160ms/epoch - 2ms/step
# Epoch 240/400
# 70/70 - 0s - loss: 0.5468 - accuracy: 0.8520 - 191ms/epoch - 3ms/step
# Epoch 241/400
# 70/70 - 0s - loss: 0.5410 - accuracy: 0.8516 - 187ms/epoch - 3ms/step
# Epoch 242/400
# 70/70 - 0s - loss: 0.5362 - accuracy: 0.8511 - 180ms/epoch - 3ms/step
# Epoch 243/400
# 70/70 - 0s - loss: 0.5332 - accuracy: 0.8507 - 183ms/epoch - 3ms/step
# Epoch 244/400
# 70/70 - 0s - loss: 0.5281 - accuracy: 0.8561 - 185ms/epoch - 3ms/step
# Epoch 245/400
# 70/70 - 0s - loss: 0.5246 - accuracy: 0.8516 - 188ms/epoch - 3ms/step
# Epoch 246/400
# 70/70 - 0s - loss: 0.5188 - accuracy: 0.8520 - 188ms/epoch - 3ms/step
# Epoch 247/400
# 70/70 - 0s - loss: 0.5139 - accuracy: 0.8601 - 184ms/epoch - 3ms/step
# Epoch 248/400
# 70/70 - 0s - loss: 0.5110 - accuracy: 0.8556 - 194ms/epoch - 3ms/step
# Epoch 249/400
# 70/70 - 0s - loss: 0.5049 - accuracy: 0.8592 - 178ms/epoch - 3ms/step
# Epoch 250/400
# 70/70 - 0s - loss: 0.4998 - accuracy: 0.8610 - 214ms/epoch - 3ms/step
# Epoch 251/400
# 70/70 - 0s - loss: 0.4955 - accuracy: 0.8570 - 180ms/epoch - 3ms/step
# Epoch 252/400
# 70/70 - 0s - loss: 0.4910 - accuracy: 0.8601 - 193ms/epoch - 3ms/step
# Epoch 253/400
# 70/70 - 0s - loss: 0.4868 - accuracy: 0.8628 - 197ms/epoch - 3ms/step
# Epoch 254/400
# 70/70 - 0s - loss: 0.4822 - accuracy: 0.8596 - 185ms/epoch - 3ms/step
# Epoch 255/400
# 70/70 - 0s - loss: 0.4781 - accuracy: 0.8610 - 174ms/epoch - 2ms/step
# Epoch 256/400
# 70/70 - 0s - loss: 0.4754 - accuracy: 0.8605 - 161ms/epoch - 2ms/step
# Epoch 257/400
# 70/70 - 0s - loss: 0.4713 - accuracy: 0.8596 - 156ms/epoch - 2ms/step
# Epoch 258/400
# 70/70 - 0s - loss: 0.4667 - accuracy: 0.8663 - 150ms/epoch - 2ms/step
# Epoch 259/400
# 70/70 - 0s - loss: 0.4628 - accuracy: 0.8623 - 150ms/epoch - 2ms/step
# Epoch 260/400
# 70/70 - 0s - loss: 0.4581 - accuracy: 0.8628 - 148ms/epoch - 2ms/step
# Epoch 261/400
# 70/70 - 0s - loss: 0.4548 - accuracy: 0.8619 - 148ms/epoch - 2ms/step
# Epoch 262/400
# 70/70 - 0s - loss: 0.4514 - accuracy: 0.8654 - 149ms/epoch - 2ms/step
# Epoch 263/400
# 70/70 - 0s - loss: 0.4477 - accuracy: 0.8659 - 150ms/epoch - 2ms/step
# Epoch 264/400
# 70/70 - 0s - loss: 0.4432 - accuracy: 0.8650 - 152ms/epoch - 2ms/step
# Epoch 265/400
# 70/70 - 0s - loss: 0.4410 - accuracy: 0.8650 - 147ms/epoch - 2ms/step
# Epoch 266/400
# 70/70 - 0s - loss: 0.4366 - accuracy: 0.8668 - 149ms/epoch - 2ms/step
# Epoch 267/400
# 70/70 - 0s - loss: 0.4330 - accuracy: 0.8713 - 151ms/epoch - 2ms/step
# Epoch 268/400
# 70/70 - 0s - loss: 0.4314 - accuracy: 0.8663 - 149ms/epoch - 2ms/step
# Epoch 269/400
# 70/70 - 0s - loss: 0.4271 - accuracy: 0.8681 - 150ms/epoch - 2ms/step
# Epoch 270/400
# 70/70 - 0s - loss: 0.4232 - accuracy: 0.8735 - 149ms/epoch - 2ms/step
# Epoch 271/400
# 70/70 - 0s - loss: 0.4198 - accuracy: 0.8717 - 148ms/epoch - 2ms/step
# Epoch 272/400
# 70/70 - 0s - loss: 0.4170 - accuracy: 0.8672 - 164ms/epoch - 2ms/step
# Epoch 273/400
# 70/70 - 0s - loss: 0.4135 - accuracy: 0.8730 - 147ms/epoch - 2ms/step
# Epoch 274/400
# 70/70 - 0s - loss: 0.4098 - accuracy: 0.8748 - 149ms/epoch - 2ms/step
# Epoch 275/400
# 70/70 - 0s - loss: 0.4070 - accuracy: 0.8726 - 148ms/epoch - 2ms/step
# Epoch 276/400
# 70/70 - 0s - loss: 0.4038 - accuracy: 0.8686 - 148ms/epoch - 2ms/step
# Epoch 277/400
# 70/70 - 0s - loss: 0.4002 - accuracy: 0.8735 - 153ms/epoch - 2ms/step
# Epoch 278/400
# 70/70 - 0s - loss: 0.3977 - accuracy: 0.8789 - 148ms/epoch - 2ms/step
# Epoch 279/400
# 70/70 - 0s - loss: 0.3951 - accuracy: 0.8766 - 149ms/epoch - 2ms/step
# Epoch 280/400
# 70/70 - 0s - loss: 0.3911 - accuracy: 0.8753 - 148ms/epoch - 2ms/step
# Epoch 281/400
# 70/70 - 0s - loss: 0.3886 - accuracy: 0.8753 - 148ms/epoch - 2ms/step
# Epoch 282/400
# 70/70 - 0s - loss: 0.3870 - accuracy: 0.8753 - 149ms/epoch - 2ms/step
# Epoch 283/400
# 70/70 - 0s - loss: 0.3826 - accuracy: 0.8713 - 154ms/epoch - 2ms/step
# Epoch 284/400
# 70/70 - 0s - loss: 0.3802 - accuracy: 0.8748 - 149ms/epoch - 2ms/step
# Epoch 285/400
# 70/70 - 0s - loss: 0.3764 - accuracy: 0.8802 - 147ms/epoch - 2ms/step
# Epoch 286/400
# 70/70 - 0s - loss: 0.3758 - accuracy: 0.8753 - 148ms/epoch - 2ms/step
# Epoch 287/400
# 70/70 - 0s - loss: 0.3725 - accuracy: 0.8775 - 149ms/epoch - 2ms/step
# Epoch 288/400
# 70/70 - 0s - loss: 0.3693 - accuracy: 0.8784 - 148ms/epoch - 2ms/step
# Epoch 289/400
# 70/70 - 0s - loss: 0.3664 - accuracy: 0.8735 - 151ms/epoch - 2ms/step
# Epoch 290/400
# 70/70 - 0s - loss: 0.3643 - accuracy: 0.8735 - 151ms/epoch - 2ms/step
# Epoch 291/400
# 70/70 - 0s - loss: 0.3604 - accuracy: 0.8784 - 146ms/epoch - 2ms/step
# Epoch 292/400
# 70/70 - 0s - loss: 0.3582 - accuracy: 0.8811 - 148ms/epoch - 2ms/step
# Epoch 293/400
# 70/70 - 0s - loss: 0.3569 - accuracy: 0.8775 - 148ms/epoch - 2ms/step
# Epoch 294/400
# 70/70 - 0s - loss: 0.3521 - accuracy: 0.8824 - 149ms/epoch - 2ms/step
# Epoch 295/400
# 70/70 - 0s - loss: 0.3513 - accuracy: 0.8766 - 150ms/epoch - 2ms/step
# Epoch 296/400
# 70/70 - 0s - loss: 0.3484 - accuracy: 0.8784 - 148ms/epoch - 2ms/step
# Epoch 297/400
# 70/70 - 0s - loss: 0.3448 - accuracy: 0.8806 - 151ms/epoch - 2ms/step
# Epoch 298/400
# 70/70 - 0s - loss: 0.3445 - accuracy: 0.8793 - 148ms/epoch - 2ms/step
# Epoch 299/400
# 70/70 - 0s - loss: 0.3411 - accuracy: 0.8780 - 150ms/epoch - 2ms/step
# Epoch 300/400
# 70/70 - 0s - loss: 0.3398 - accuracy: 0.8780 - 148ms/epoch - 2ms/step
# Epoch 301/400
# 70/70 - 0s - loss: 0.3364 - accuracy: 0.8824 - 148ms/epoch - 2ms/step
# Epoch 302/400
# 70/70 - 0s - loss: 0.3352 - accuracy: 0.8771 - 148ms/epoch - 2ms/step
# Epoch 303/400
# 70/70 - 0s - loss: 0.3330 - accuracy: 0.8815 - 167ms/epoch - 2ms/step
# Epoch 304/400
# 70/70 - 0s - loss: 0.3314 - accuracy: 0.8797 - 148ms/epoch - 2ms/step
# Epoch 305/400
# 70/70 - 0s - loss: 0.3274 - accuracy: 0.8797 - 147ms/epoch - 2ms/step
# Epoch 306/400
# 70/70 - 0s - loss: 0.3259 - accuracy: 0.8860 - 147ms/epoch - 2ms/step
# Epoch 307/400
# 70/70 - 0s - loss: 0.3243 - accuracy: 0.8833 - 147ms/epoch - 2ms/step
# Epoch 308/400
# 70/70 - 0s - loss: 0.3220 - accuracy: 0.8838 - 148ms/epoch - 2ms/step
# Epoch 309/400
# 70/70 - 0s - loss: 0.3192 - accuracy: 0.8847 - 150ms/epoch - 2ms/step
# Epoch 310/400
# 70/70 - 0s - loss: 0.3165 - accuracy: 0.8802 - 151ms/epoch - 2ms/step
# Epoch 311/400
# 70/70 - 0s - loss: 0.3163 - accuracy: 0.8860 - 148ms/epoch - 2ms/step
# Epoch 312/400
# 70/70 - 0s - loss: 0.3159 - accuracy: 0.8775 - 147ms/epoch - 2ms/step
# Epoch 313/400
# 70/70 - 0s - loss: 0.3115 - accuracy: 0.8878 - 149ms/epoch - 2ms/step
# Epoch 314/400
# 70/70 - 0s - loss: 0.3099 - accuracy: 0.8820 - 150ms/epoch - 2ms/step
# Epoch 315/400
# 70/70 - 0s - loss: 0.3087 - accuracy: 0.8842 - 153ms/epoch - 2ms/step
# Epoch 316/400
# 70/70 - 0s - loss: 0.3075 - accuracy: 0.8806 - 147ms/epoch - 2ms/step
# Epoch 317/400
# 70/70 - 0s - loss: 0.3048 - accuracy: 0.8833 - 152ms/epoch - 2ms/step
# Epoch 318/400
# 70/70 - 0s - loss: 0.3029 - accuracy: 0.8873 - 148ms/epoch - 2ms/step
# Epoch 319/400
# 70/70 - 0s - loss: 0.3004 - accuracy: 0.8847 - 148ms/epoch - 2ms/step
# Epoch 320/400
# 70/70 - 0s - loss: 0.2980 - accuracy: 0.8847 - 147ms/epoch - 2ms/step
# Epoch 321/400
# 70/70 - 0s - loss: 0.2961 - accuracy: 0.8856 - 148ms/epoch - 2ms/step
# Epoch 322/400
# 70/70 - 0s - loss: 0.2956 - accuracy: 0.8873 - 148ms/epoch - 2ms/step
# Epoch 323/400
# 70/70 - 0s - loss: 0.2939 - accuracy: 0.8815 - 152ms/epoch - 2ms/step
# Epoch 324/400
# 70/70 - 0s - loss: 0.2920 - accuracy: 0.8909 - 141ms/epoch - 2ms/step
# Epoch 325/400
# 70/70 - 0s - loss: 0.2898 - accuracy: 0.8838 - 139ms/epoch - 2ms/step
# Epoch 326/400
# 70/70 - 0s - loss: 0.2885 - accuracy: 0.8865 - 138ms/epoch - 2ms/step
# Epoch 327/400
# 70/70 - 0s - loss: 0.2862 - accuracy: 0.8842 - 138ms/epoch - 2ms/step
# Epoch 328/400
# 70/70 - 0s - loss: 0.2858 - accuracy: 0.8865 - 141ms/epoch - 2ms/step
# Epoch 329/400
# 70/70 - 0s - loss: 0.2838 - accuracy: 0.8869 - 139ms/epoch - 2ms/step
# Epoch 330/400
# 70/70 - 0s - loss: 0.2829 - accuracy: 0.8865 - 146ms/epoch - 2ms/step
# Epoch 331/400
# 70/70 - 0s - loss: 0.2823 - accuracy: 0.8887 - 141ms/epoch - 2ms/step
# Epoch 332/400
# 70/70 - 0s - loss: 0.2803 - accuracy: 0.8927 - 138ms/epoch - 2ms/step
# Epoch 333/400
# 70/70 - 0s - loss: 0.2782 - accuracy: 0.8869 - 152ms/epoch - 2ms/step
# Epoch 334/400
# 70/70 - 0s - loss: 0.2771 - accuracy: 0.8887 - 138ms/epoch - 2ms/step
# Epoch 335/400
# 70/70 - 0s - loss: 0.2757 - accuracy: 0.8851 - 139ms/epoch - 2ms/step
# Epoch 336/400
# 70/70 - 0s - loss: 0.2746 - accuracy: 0.8865 - 140ms/epoch - 2ms/step
# Epoch 337/400
# 70/70 - 0s - loss: 0.2735 - accuracy: 0.8873 - 141ms/epoch - 2ms/step
# Epoch 338/400
# 70/70 - 0s - loss: 0.2720 - accuracy: 0.8865 - 142ms/epoch - 2ms/step
# Epoch 339/400
# 70/70 - 0s - loss: 0.2706 - accuracy: 0.8882 - 139ms/epoch - 2ms/step
# Epoch 340/400
# 70/70 - 0s - loss: 0.2680 - accuracy: 0.8873 - 138ms/epoch - 2ms/step
# Epoch 341/400
# 70/70 - 0s - loss: 0.2660 - accuracy: 0.8905 - 139ms/epoch - 2ms/step
# Epoch 342/400
# 70/70 - 0s - loss: 0.2663 - accuracy: 0.8873 - 138ms/epoch - 2ms/step
# Epoch 343/400
# 70/70 - 0s - loss: 0.2647 - accuracy: 0.8905 - 139ms/epoch - 2ms/step
# Epoch 344/400
# 70/70 - 0s - loss: 0.2628 - accuracy: 0.8905 - 139ms/epoch - 2ms/step
# Epoch 345/400
# 70/70 - 0s - loss: 0.2624 - accuracy: 0.8896 - 145ms/epoch - 2ms/step
# Epoch 346/400
# 70/70 - 0s - loss: 0.2604 - accuracy: 0.8882 - 137ms/epoch - 2ms/step
# Epoch 347/400
# 70/70 - 0s - loss: 0.2602 - accuracy: 0.8891 - 140ms/epoch - 2ms/step
# Epoch 348/400
# 70/70 - 0s - loss: 0.2580 - accuracy: 0.8860 - 138ms/epoch - 2ms/step
# Epoch 349/400
# 70/70 - 0s - loss: 0.2570 - accuracy: 0.8865 - 139ms/epoch - 2ms/step
# Epoch 350/400
# 70/70 - 0s - loss: 0.2561 - accuracy: 0.8865 - 140ms/epoch - 2ms/step
# Epoch 351/400
# 70/70 - 0s - loss: 0.2543 - accuracy: 0.8882 - 138ms/epoch - 2ms/step
# Epoch 352/400
# 70/70 - 0s - loss: 0.2534 - accuracy: 0.8860 - 140ms/epoch - 2ms/step
# Epoch 353/400
# 70/70 - 0s - loss: 0.2513 - accuracy: 0.8865 - 139ms/epoch - 2ms/step
# Epoch 354/400
# 70/70 - 0s - loss: 0.2519 - accuracy: 0.8856 - 138ms/epoch - 2ms/step
# Epoch 355/400
# 70/70 - 0s - loss: 0.2511 - accuracy: 0.8865 - 138ms/epoch - 2ms/step
# Epoch 356/400
# 70/70 - 0s - loss: 0.2495 - accuracy: 0.8869 - 141ms/epoch - 2ms/step
# Epoch 357/400
# 70/70 - 0s - loss: 0.2482 - accuracy: 0.8878 - 139ms/epoch - 2ms/step
# Epoch 358/400
# 70/70 - 0s - loss: 0.2466 - accuracy: 0.8865 - 138ms/epoch - 2ms/step
# Epoch 359/400
# 70/70 - 0s - loss: 0.2463 - accuracy: 0.8869 - 145ms/epoch - 2ms/step
# Epoch 360/400
# 70/70 - 0s - loss: 0.2454 - accuracy: 0.8900 - 142ms/epoch - 2ms/step
# Epoch 361/400
# 70/70 - 0s - loss: 0.2445 - accuracy: 0.8873 - 141ms/epoch - 2ms/step
# Epoch 362/400
# 70/70 - 0s - loss: 0.2427 - accuracy: 0.8873 - 153ms/epoch - 2ms/step
# Epoch 363/400
# 70/70 - 0s - loss: 0.2424 - accuracy: 0.8941 - 137ms/epoch - 2ms/step
# Epoch 364/400
# 70/70 - 0s - loss: 0.2402 - accuracy: 0.8914 - 140ms/epoch - 2ms/step
# Epoch 365/400
# 70/70 - 0s - loss: 0.2420 - accuracy: 0.8842 - 138ms/epoch - 2ms/step
# Epoch 366/400
# 70/70 - 0s - loss: 0.2392 - accuracy: 0.8891 - 141ms/epoch - 2ms/step
# Epoch 367/400
# 70/70 - 0s - loss: 0.2388 - accuracy: 0.8914 - 139ms/epoch - 2ms/step
# Epoch 368/400
# 70/70 - 0s - loss: 0.2383 - accuracy: 0.8896 - 141ms/epoch - 2ms/step
# Epoch 369/400
# 70/70 - 0s - loss: 0.2366 - accuracy: 0.8865 - 140ms/epoch - 2ms/step
# Epoch 370/400
# 70/70 - 0s - loss: 0.2358 - accuracy: 0.8865 - 139ms/epoch - 2ms/step
# Epoch 371/400
# 70/70 - 0s - loss: 0.2343 - accuracy: 0.8900 - 139ms/epoch - 2ms/step
# Epoch 372/400
# 70/70 - 0s - loss: 0.2355 - accuracy: 0.8860 - 139ms/epoch - 2ms/step
# Epoch 373/400
# 70/70 - 0s - loss: 0.2340 - accuracy: 0.8873 - 145ms/epoch - 2ms/step
# Epoch 374/400
# 70/70 - 0s - loss: 0.2325 - accuracy: 0.8842 - 142ms/epoch - 2ms/step
# Epoch 375/400
# 70/70 - 0s - loss: 0.2314 - accuracy: 0.8865 - 137ms/epoch - 2ms/step
# Epoch 376/400
# 70/70 - 0s - loss: 0.2303 - accuracy: 0.8829 - 139ms/epoch - 2ms/step
# Epoch 377/400
# 70/70 - 0s - loss: 0.2306 - accuracy: 0.8842 - 138ms/epoch - 2ms/step
# Epoch 378/400
# 70/70 - 0s - loss: 0.2300 - accuracy: 0.8873 - 138ms/epoch - 2ms/step
# Epoch 379/400
# 70/70 - 0s - loss: 0.2287 - accuracy: 0.8873 - 139ms/epoch - 2ms/step
# Epoch 380/400
# 70/70 - 0s - loss: 0.2273 - accuracy: 0.8873 - 141ms/epoch - 2ms/step
# Epoch 381/400
# 70/70 - 0s - loss: 0.2266 - accuracy: 0.8869 - 137ms/epoch - 2ms/step
# Epoch 382/400
# 70/70 - 0s - loss: 0.2265 - accuracy: 0.8833 - 139ms/epoch - 2ms/step
# Epoch 383/400
# 70/70 - 0s - loss: 0.2248 - accuracy: 0.8900 - 140ms/epoch - 2ms/step
# Epoch 384/400
# 70/70 - 0s - loss: 0.2241 - accuracy: 0.8860 - 138ms/epoch - 2ms/step
# Epoch 385/400
# 70/70 - 0s - loss: 0.2233 - accuracy: 0.8851 - 137ms/epoch - 2ms/step
# Epoch 386/400
# 70/70 - 0s - loss: 0.2237 - accuracy: 0.8847 - 138ms/epoch - 2ms/step
# Epoch 387/400
# 70/70 - 0s - loss: 0.2218 - accuracy: 0.8847 - 143ms/epoch - 2ms/step
# Epoch 388/400
# 70/70 - 0s - loss: 0.2217 - accuracy: 0.8900 - 142ms/epoch - 2ms/step
# Epoch 389/400
# 70/70 - 0s - loss: 0.2217 - accuracy: 0.8829 - 139ms/epoch - 2ms/step
# Epoch 390/400
# 70/70 - 0s - loss: 0.2206 - accuracy: 0.8887 - 153ms/epoch - 2ms/step
# Epoch 391/400
# 70/70 - 0s - loss: 0.2218 - accuracy: 0.8869 - 140ms/epoch - 2ms/step
# Epoch 392/400
# 70/70 - 0s - loss: 0.2203 - accuracy: 0.8887 - 139ms/epoch - 2ms/step
# Epoch 393/400
# 70/70 - 0s - loss: 0.2185 - accuracy: 0.8900 - 140ms/epoch - 2ms/step
# Epoch 394/400
# 70/70 - 0s - loss: 0.2189 - accuracy: 0.8882 - 143ms/epoch - 2ms/step
# Epoch 395/400
# 70/70 - 0s - loss: 0.2173 - accuracy: 0.8900 - 139ms/epoch - 2ms/step
# Epoch 396/400
# 70/70 - 0s - loss: 0.2166 - accuracy: 0.8878 - 137ms/epoch - 2ms/step
# Epoch 397/400
# 70/70 - 0s - loss: 0.2160 - accuracy: 0.8851 - 139ms/epoch - 2ms/step
# Epoch 398/400
# 70/70 - 0s - loss: 0.2155 - accuracy: 0.8873 - 139ms/epoch - 2ms/step
# Epoch 399/400
# 70/70 - 0s - loss: 0.2154 - accuracy: 0.8856 - 139ms/epoch - 2ms/step
# Epoch 400/400
# 70/70 - 0s - loss: 0.2144 - accuracy: 0.8865 - 140ms/epoch - 2ms/step

# %%
print(gen_top_next_word(
    model_n_prev_versions[1], tok, maxlen, "i'm like It makes", 20))
# Out:
# ['quick', 'me', 'of', 'know', 'their', "i'd", 'have', 'be', 'little', 'his', 'the', "don't", 'wax', 'that', 'is', 'railroads', 'must', 'fort', 'stop', 'arkansas']

# %%
model_n_prev_versions
# Out:
# {1: <keras.src.engine.sequential.Sequential at 0x1bd8c7dcdd0>,
#  2: <keras.src.engine.sequential.Sequential at 0x1bd8c7d3b10>}

# %%
def save_models_and_tok():
    for k, v in model_n_prev_versions.items():
        v.save(f'models\model_{k}_prev.h5')
    dump(tok, open('tokenizer.pkl', 'wb'))

# %%
save_models_and_tok()

# %%
model1 = load_model('models\model_2_prev.h5')
maxlen = 3

# %%
tok = load(open('tokenizer.pkl', 'rb'))

# %%
print(
    gen_top_next_word(model1, tok, maxlen, "on makes", 100)
)
# Out:
# ['but', 'children', 'if', 'time', 'his', 'last', "i'm", 'and', 'again', 'without', 'that', 'about', 'wails', 'so', 'heir', 'what', 'their', 'even', 'this', 'fingers', 'my', 'are', 'not', 'old', 'california', 'years', 'arkansas', 'way', 'up', 'problem', 'distance', 'worked', 'on', 'concrete', 'wax', 'does', 'one', 'just', 'alone', 'the', 'covered', 'fire', 'layer', 'spotted', 'bill', "we're", 'marks', 'getting', 'stepping', 'dart', 'anastasios', 'freezing', 'gory', 'yellow', 'for', 'brick', 'he', 'breath', 'then', 'pulse', 'already', 'we', 'pause', 'nearly', 'along', 'sense', 'horse', 'ecstasy', 'a', 'know', 'tore', 'fasten', 'few', 'life', "that's", 'to', 'two', 'was', 'poison', 'any', 'trace', 'boot', 'mouth', 'seem', 'little', 'pouched', 'restless', 'other', 'many', 'goddammit', 'stretch', 'by', 'explodes', 'groaning', 'or', 'across', 'women', 'right', 'days', 'as']
